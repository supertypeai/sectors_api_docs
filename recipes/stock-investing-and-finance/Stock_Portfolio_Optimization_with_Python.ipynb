# %% [markdown]
# # *Quick Introduction *
#
# This notebook is a supplementary resource for the workshop “Stock Portfolio Optimization with Python” using the Sectors API. It covers these topics: stock investment background and understanding the Sectors API, stock selection overview and two stock portfolio optimization models, followed by further recommendations and insights.

# %% [markdown]
# # Section 1 - Sectors API & Stock Investment Overview
#
# When considering stock investments, individual investors typically focus on key questions such as: Which stocks to buy? How many shares? What’s the price, growth potential, and risk?
#
# Using the Sectors API, investors gain access to valuable data from the “**Companies by Index**” and “**Daily Transaction Data**” endpoints, including stock indexes, dates, closing prices, volumes, and market capitalizations. Next, the “**Company Report**” API provides additional insights such as EPS, dividends, growth metrics, and other relevant financial information.
#
# In **Section 3**, we will explore how to effectively query this data from the API to build a portfolio optimization model. However, before diving into optimization, it’s crucial to **understand the available stock indexes** and their **respective investment purposes**.

# %%
import pandas as pd

index_data = {

              #list of stock indexes from Sectors API

    'Index': ['FTSE', 'IDX30', 'IDXBUMN20', 'IDXESGL', 'IDXG30', 'IDXHIDIV20',
              'IDXQ30', 'IDXV30', 'JII70', 'KOMPAS100', 'LQ45', 'SMInfra18',
              'SRIKEHA18', 'SRIKEHATI'],

    'Focus': ['Globally recognized index of large-cap companies',
              'Top 30 stocks by market cap and liquidity',
              'Top 20 government-owned enterprises (BUMN)',
              'Stocks meeting ESG (environmental, social, governance) standards',
              'Large-cap, high liquidity growth stocks',
              '20 stocks with high dividend yields',
              'Focus on quality stocks based on financial metrics',
              'Focus on value stocks trading below intrinsic value',
              '70 stocks complying with Shariah (Islamic law)',
              '100 most liquid, actively traded stocks',
              'Top 45 most liquid stocks with large market caps',
              '18 infrastructure-related stocks',
              'Tracks sustainability and social responsibility',
              'Sustainability and ethical investing'],

    'Investment Use': ['For investors seeking to track global or broad market performance',
                       'Suitable for blue-chip stock investors looking for stable and liquid companies',
                       'For exposure to state-owned enterprises (SOEs) benefiting from government policies',
                       'Ideal for socially responsible investors focused on sustainability and ethical investing',
                       'For growth-oriented investors looking for long-term capital appreciation',
                       'Attractive to income-seeking investors focused on dividend income',
                       'Suitable for long-term investors seeking companies with strong fundamentals',
                       'Ideal for value investors looking for undervalued stocks',
                       'Suitable for Shariah-compliant investors following Islamic investment principles',
                       'For investors seeking diversified exposure to Indonesia’s liquid stocks',
                       'Blue-chip focused, for investors looking for stability and long-term growth potential',
                       'For investors bullish on infrastructure growth and development projects in Indonesia',
                       'Ideal for ESG investors prioritizing sustainable business practices',
                       'Same as SRIKEHA18, for socially responsible investors']
}

# Load into a pandas DataFrame
df_index_info = pd.DataFrame(index_data)

# Display the DataFrame
df_index_info
# Out:
#          Index                                              Focus  \
# 0         FTSE   Globally recognized index of large-cap companies
# 1        IDX30          Top 30 stocks by market cap and liquidity
# 2    IDXBUMN20         Top 20 government-owned enterprises (BUMN)
# 3      IDXESGL  Stocks meeting ESG (environmental, social, gov...
# 4       IDXG30            Large-cap, high liquidity growth stocks
# 5   IDXHIDIV20                20 stocks with high dividend yields
# 6       IDXQ30  Focus on quality stocks based on financial met...
# 7       IDXV30  Focus on value stocks trading below intrinsic ...
# 8        JII70     70 stocks complying with Shariah (Islamic law)
# 9    KOMPAS100            100 most liquid, actively traded stocks
# 10        LQ45   Top 45 most liquid stocks with large market caps
# 11   SMInfra18                   18 infrastructure-related stocks
# 12   SRIKEHA18    Tracks sustainability and social responsibility
# 13   SRIKEHATI               Sustainability and ethical investing
#
#                                        Investment Use
# 0   For investors seeking to track global or broad...
# 1   Suitable for blue-chip stock investors looking...
# 2   For exposure to state-owned enterprises (SOEs)...
# 3   Ideal for socially responsible investors focus...
# 4   For growth-oriented investors looking for long...
# 5   Attractive to income-seeking investors focused...
# 6   Suitable for long-term investors seeking compa...
# 7   Ideal for value investors looking for underval...
# 8   Suitable for Shariah-compliant investors follo...
# 9   For investors seeking diversified exposure to ...
# 10  Blue-chip focused, for investors looking for s...
# 11  For investors bullish on infrastructure growth...
# 12  Ideal for ESG investors prioritizing sustainab...
# 13  Same as SRIKEHA18, for socially responsible in...

# %% [markdown]
# Which index caught your attention? What do you want to choose?

# %% [markdown]
# # Section 2 - Where to start?
# Recommendation: **Match your investment goals with the property of stock index**

# %%
import pandas as pd

# Dictionary representing the stock index information with persona examples
index_criteria = {
    'Criteria': [
        'Liquidity & Stability',
        'Government-Owned Enterprises',
        'Dividend Focus',
        'Growth-Oriented',
        'Value Stocks',
        'High-Quality Financials',
        'Shariah-Compliant Investments',
        'Socially Responsible Investments',
        'Infrastructure Focus',
        'Broad Market Exposure'
    ],
    'Description': [
        'Investors looking for highly liquid and stable stocks that are less volatile.',
        'For investors interested in companies benefiting from government backing and policies.',
        'Ideal for those seeking regular income from dividends.',
        'Suitable for long-term investors focusing on capital appreciation.',
        'Investors seeking undervalued stocks trading below intrinsic value.',
        'Focus on stocks with strong fundamentals and good financial health.',
        'For investors following Islamic principles.',
        'Investors interested in ESG (environmental, social, governance) and ethical business practices.',
        'For investors bullish on Indonesia\'s infrastructure growth.',
        'For investors wanting diversified exposure across large segments of the market.'
    ],
    'Persona': [
        'Maria, a risk-averse retiree seeking low volatility and stable returns.',
        'Adi, a public sector enthusiast who trusts government-driven initiatives.',
        'Siti, a conservative investor who prefers stable income from dividends.',
        'Kevin, a young professional aiming for long-term wealth through capital growth.',
        'Tom, a value investor who looks for bargain stocks below intrinsic value.',
        'Dewi, a financial analyst who invests in companies with strong fundamentals.',
        'Ahmad, a devout Muslim who prioritizes Shariah-compliant investments.',
        'Sarah, an environmentally conscious investor focusing on ethical companies.',
        'Indra, an infrastructure expert optimistic about Indonesia\'s construction growth.',
        'Emily, a diversified investor looking for broad market exposure and lower risk.'
    ],
    'Recommended Index': [
        'IDX30, LQ45, KOMPAS100',
        'IDXBUMN20',
        'IDXHIDIV20',
        'IDXG30',
        'IDXV30',
        'IDXQ30',
        'JII70',
        'IDXESGL, SRIKEHA18, SRIKEHATI',
        'SMINFA18',
        'FTSE, KOMPAS100'
    ]
}

df_index_criteria = pd.DataFrame(index_criteria)

df_index_criteria
# Out:
#                            Criteria  \
# 0             Liquidity & Stability
# 1      Government-Owned Enterprises
# 2                    Dividend Focus
# 3                   Growth-Oriented
# 4                      Value Stocks
# 5           High-Quality Financials
# 6     Shariah-Compliant Investments
# 7  Socially Responsible Investments
# 8              Infrastructure Focus
# 9             Broad Market Exposure
#
#                                          Description  \
# 0  Investors looking for highly liquid and stable...
# 1  For investors interested in companies benefiti...
# 2  Ideal for those seeking regular income from di...
# 3  Suitable for long-term investors focusing on c...
# 4  Investors seeking undervalued stocks trading b...
# 5  Focus on stocks with strong fundamentals and g...
# 6        For investors following Islamic principles.
# 7  Investors interested in ESG (environmental, so...
# 8  For investors bullish on Indonesia's infrastru...
# 9  For investors wanting diversified exposure acr...
#
#                                              Persona  \
# 0  Maria, a risk-averse retiree seeking low volat...
# 1  Adi, a public sector enthusiast who trusts gov...
# 2  Siti, a conservative investor who prefers stab...
# 3  Kevin, a young professional aiming for long-te...
# 4  Tom, a value investor who looks for bargain st...
# 5  Dewi, a financial analyst who invests in compa...
# 6  Ahmad, a devout Muslim who prioritizes Shariah...
# 7  Sarah, an environmentally conscious investor f...
# 8  Indra, an infrastructure expert optimistic abo...
# 9  Emily, a diversified investor looking for broa...
#
#                Recommended Index
# 0         IDX30, LQ45, KOMPAS100
# 1                      IDXBUMN20
# 2                     IDXHIDIV20
# 3                         IDXG30
# 4                         IDXV30
# 5                         IDXQ30
# 6                          JII70
# 7  IDXESGL, SRIKEHA18, SRIKEHATI
# 8                       SMINFA18
# 9                FTSE, KOMPAS100

# %% [markdown]
# While it’s crucial to evaluate a stock’s internal characteristics—such as its nature, properties, and the type of investor it appeals to—external macroeconomic factors play an equally important role in guiding stock index selection. **These broader economic conditions, including inflation rates, government policies, and global market trends, are key determinants in the performance of various sectors.** Therefore, understanding both your investment persona and the prevailing macroeconomic landscape is essential for making informed decisions.

# %% [markdown]
# Now let’s assume my client is Indra, an infrastructure expert optimistic about Indonesia’s construction growth. To confirm focusing solely on SMINFA18, we need to observe the following macroeconomic factors:
#
#
# *   **Government infrastructure spending**: Announcements of new airports and highways as public projects.
# *   **Interest Rate policies**: Indonesia’s central bank lowers interest rates.
# *   **Commodity prices**: Steel and cement prices drop due to global supply chain restructuring.
# *   **Foreign Direct investment**: China increases investment in Indonesia’s high-speed rail projects.
#
# We will build the following content for our client Indra.

# %% [markdown]
# How to choose specific stocks from an index will be discussed in section 4.

# %% [markdown]
# # Section 3 - Data Collection from Sectors API

# %% [markdown]
# ## Section 3.1 - Stock Price Information

# %%
# Retrive Stock index from "Companies by Index" API

import time
import requests
from google.colab import userdata

# Retrieve the API key securely
api_key = userdata.get('SECTORS_API_KEY')

# Define the API URL
url = "https://api.sectors.app/v1/index/sminfra18/"

# Pass the API key in the header
headers = {"Authorization": api_key}

# Make the API request
response_company_index = requests.get(url, headers=headers)

print(response_company_index.text)
# Out:
# [{"symbol":"ADHI.JK","company_name":"PT Adhi Karya (Persero) Tbk."},{"symbol":"AKRA.JK","company_name":"PT AKR Corporindo Tbk."},{"symbol":"BBNI.JK","company_name":"PT Bank Negara Indonesia (Persero) Tbk"},{"symbol":"BBRI.JK","company_name":"PT Bank Rakyat Indonesia (Persero) Tbk"},{"symbol":"BMRI.JK","company_name":"PT Bank Mandiri (Persero) Tbk"},{"symbol":"EXCL.JK","company_name":"PT XL Axiata Tbk"},{"symbol":"INTP.JK","company_name":"Indocement Tunggal Prakarsa Tbk"},{"symbol":"ISAT.JK","company_name":"PT Indosat Tbk"},{"symbol":"JSMR.JK","company_name":"PT Jasa Marga Tbk"},{"symbol":"MEDC.JK","company_name":"PT Medco Energi Internasional Tbk"},{"symbol":"PGAS.JK","company_name":"PT Perusahaan Gas Negara Tbk."},{"symbol":"PTPP.JK","company_name":"PP (Persero) Tbk"},{"symbol":"SMGR.JK","company_name":"Semen Indonesia (Persero) Tbk"},{"symbol":"SSIA.JK","company_name":"PT Surya Semesta Internusa Tbk"},{"symbol":"TBIG.JK","company_name":"PT Tower Bersama Infrastructure Tbk"},{"symbol":"TLKM.JK","company_name":"PT Telkom Indonesia (Persero) Tbk"},{"symbol":"TOWR.JK","company_name":"Sarana Menara Nusantara Tbk"},{"symbol":"UNTR.JK","company_name":"United Tractors Tbk"}]

# %%
# Retrieve date and price from "Daily Transaction Data" API

from datetime import datetime, timedelta

# Function to calculate the date 90 days ago from today
def calculate_start_date(days_ago=90):
    return (datetime.now() - timedelta(days=days_ago)).strftime('%Y-%m-%d')

# Calculate the start date 90 days ago
start_date = calculate_start_date()

# Looping API info
history_sminfra18 = []

for i, x in enumerate(response_company_index.json()):

  # Define the URL for the API endpoint
  url = "https://api.sectors.app/v1/daily/" + response_company_index.json()[i]['symbol'] + "/"

  # Define the query string with the calculated start date
  querystring = {"start": start_date}

  headers = {"Authorization": userdata.get('SECTORS_API_KEY')}

  response_daily_transaction_data = requests.request("GET", url, headers=headers, params=querystring)

  # Append the result into target list
  history_sminfra18.append(response_daily_transaction_data.json())

  time.sleep(1)

# %%
history_sminfra18
# Out:
# [[{'symbol': 'ADHI.JK',
#    'date': '2024-07-10',
#    'close': 250,
#    'volume': 80145800,
#    'market_cap': 2101902442496},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-11',
#    'close': 248,
#    'volume': 37656100,
#    'market_cap': 2085087215616},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-12',
#    'close': 262,
#    'volume': 138657900,
#    'market_cap': 2202793672704},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-15',
#    'close': 256,
#    'volume': 49577700,
#    'market_cap': 2152348123136},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-16',
#    'close': 248,
#    'volume': 29521600,
#    'market_cap': 2085087257962},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-17',
#    'close': 260,
#    'volume': 52984500,
#    'market_cap': 2185978576896},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-18',
#    'close': 256,
#    'volume': 31999200,
#    'market_cap': 2152348123136},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-19',
#    'close': 252,
#    'volume': 21461700,
#    'market_cap': 2118717669376},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-22',
#    'close': 254,
#    'volume': 37583700,
#    'market_cap': 2135532896256},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-23',
#    'close': 252,
#    'volume': 14073400,
#    'market_cap': 2118717669376},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-24',
#    'close': 240,
#    'volume': 31302900,
#    'market_cap': 2017826308096},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-25',
#    'close': 242,
#    'volume': 17136100,
#    'market_cap': 2034641534976},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-26',
#    'close': 244,
#    'volume': 16246200,
#    'market_cap': 2051456761856},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-29',
#    'close': 248,
#    'volume': 15831500,
#    'market_cap': 2085087215616},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-30',
#    'close': 240,
#    'volume': 8711300,
#    'market_cap': 2017826308096},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-07-31',
#    'close': 236,
#    'volume': 11874600,
#    'market_cap': 1984195985408},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-08-01',
#    'close': 248,
#    'volume': 82397800,
#    'market_cap': 2085087215616},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-08-02',
#    'close': 242,
#    'volume': 13831200,
#    'market_cap': 2034641534976},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-08-05',
#    'close': 232,
#    'volume': 27481400,
#    'market_cap': 1950565531648},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-08-06',
#    'close': 238,
#    'volume': 16545100,
#    'market_cap': 2001011081216},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-08-07',
#    'close': 238,
#    'volume': 19014900,
#    'market_cap': 2001011081216},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-08-08',
#    'close': 236,
#    'volume': 6718300,
#    'market_cap': 1984195985408},
#   {'symbol': 'ADHI.JK',
#    'date': '2024-08-09',
#    'close': 252,
#    'volume': 71205700,
#    'market_cap': 2118717669376}],
#  [{'symbol': 'AKRA.JK',
#    'date': '2024-07-10',
#    'close': 1510,
#    'volume': 47426100,
#    'market_cap': 29803172331520},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-11',
#    'close': 1505,
#    'volume': 39265500,
#    'market_cap': 29704486649856},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-12',
#    'close': 1500,
#    'volume': 53464000,
#    'market_cap': 29605800968192},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-15',
#    'close': 1505,
#    'volume': 35246200,
#    'market_cap': 29704486649856},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-16',
#    'close': 1505,
#    'volume': 40727000,
#    'market_cap': 29901858013184},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-17',
#    'close': 1505,
#    'volume': 9934200,
#    'market_cap': 29901858013184},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-18',
#    'close': 1520,
#    'volume': 24084000,
#    'market_cap': 30000545792000},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-19',
#    'close': 1515,
#    'volume': 23974400,
#    'market_cap': 29901858013184},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-22',
#    'close': 1510,
#    'volume': 22977900,
#    'market_cap': 29803172331520},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-23',
#    'close': 1505,
#    'volume': 14435800,
#    'market_cap': 29704486649856},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-24',
#    'close': 1505,
#    'volume': 17161700,
#    'market_cap': 29704486649856},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-25',
#    'close': 1510,
#    'volume': 30671700,
#    'market_cap': 29803172331520},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-26',
#    'close': 1555,
#    'volume': 56522600,
#    'market_cap': 30691347660800},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-29',
#    'close': 1530,
#    'volume': 71126900,
#    'market_cap': 30197917155328},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-30',
#    'close': 1525,
#    'volume': 46147900,
#    'market_cap': 30099231473664},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-07-31',
#    'close': 1515,
#    'volume': 44530100,
#    'market_cap': 29901858013184},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-08-01',
#    'close': 1520,
#    'volume': 43081000,
#    'market_cap': 30000545792000},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-08-02',
#    'close': 1525,
#    'volume': 44466400,
#    'market_cap': 30099231473664},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-08-05',
#    'close': 1405,
#    'volume': 76682000,
#    'market_cap': 27730766725120},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-08-06',
#    'close': 1405,
#    'volume': 36130900,
#    'market_cap': 27730766725120},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-08-07',
#    'close': 1440,
#    'volume': 36483600,
#    'market_cap': 28421568593920},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-08-08',
#    'close': 1420,
#    'volume': 14812500,
#    'market_cap': 28026825867264},
#   {'symbol': 'AKRA.JK',
#    'date': '2024-08-09',
#    'close': 1450,
#    'volume': 25551400,
#    'market_cap': 28618939957248}],
#  [{'symbol': 'BBNI.JK',
#    'date': '2024-07-10',
#    'close': 4820,
#    'volume': 48700200,
#    'market_cap': 179533424623616},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-11',
#    'close': 4870,
#    'volume': 37573700,
#    'market_cap': 181395813040128},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-12',
#    'close': 5025,
#    'volume': 151520700,
#    'market_cap': 187169188610048},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-15',
#    'close': 5025,
#    'volume': 94794900,
#    'market_cap': 187169188610048},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-16',
#    'close': 4980,
#    'volume': 66371200,
#    'market_cap': 185493034069131},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-17',
#    'close': 5000,
#    'volume': 59615300,
#    'market_cap': 186237986013184},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-18',
#    'close': 5075,
#    'volume': 86127800,
#    'market_cap': 189031560249344},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-19',
#    'close': 5100,
#    'volume': 66907300,
#    'market_cap': 189962746068992},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-22',
#    'close': 5100,
#    'volume': 32378000,
#    'market_cap': 190893948665856},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-23',
#    'close': 5050,
#    'volume': 30554100,
#    'market_cap': 188100374429696},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-24',
#    'close': 5100,
#    'volume': 23442100,
#    'market_cap': 189962746068992},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-25',
#    'close': 5025,
#    'volume': 52463300,
#    'market_cap': 187169188610048},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-26',
#    'close': 5000,
#    'volume': 41982600,
#    'market_cap': 186237986013184},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-29',
#    'close': 5025,
#    'volume': 19854800,
#    'market_cap': 187169188610048},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-30',
#    'close': 4950,
#    'volume': 36830400,
#    'market_cap': 183457900658688},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-07-31',
#    'close': 4970,
#    'volume': 34106000,
#    'market_cap': 186237986013184},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-08-01',
#    'close': 5075,
#    'volume': 54207300,
#    'market_cap': 189031560249344},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-08-02',
#    'close': 5100,
#    'volume': 75959300,
#    'market_cap': 189017232506880},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-08-05',
#    'close': 4960,
#    'volume': 65485300,
#    'market_cap': 186237986013184},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-08-06',
#    'close': 5025,
#    'volume': 51827100,
#    'market_cap': 187169188610048},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-08-07',
#    'close': 5000,
#    'volume': 32547900,
#    'market_cap': 186237986013184},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-08-08',
#    'close': 5025,
#    'volume': 51493100,
#    'market_cap': 187169188610048},
#   {'symbol': 'BBNI.JK',
#    'date': '2024-08-09',
#    'close': 5125,
#    'volume': 33031700,
#    'market_cap': 189962746068992}],
#  [{'symbol': 'BBRI.JK',
#    'date': '2024-07-10',
#    'close': 4850,
#    'volume': 167619700,
#    'market_cap': 731336360853504},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-11',
#    'close': 4840,
#    'volume': 170461300,
#    'market_cap': 729828424679424},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-12',
#    'close': 4900,
#    'volume': 301125400,
#    'market_cap': 738875907506176},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-15',
#    'close': 4820,
#    'volume': 188713000,
#    'market_cap': 726812619440128},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-16',
#    'close': 4730,
#    'volume': 189271400,
#    'market_cap': 729828424679424},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-17',
#    'close': 4760,
#    'volume': 263325400,
#    'market_cap': 731336360853504},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-18',
#    'close': 4890,
#    'volume': 296614900,
#    'market_cap': 737367971332096},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-19',
#    'close': 4900,
#    'volume': 135104800,
#    'market_cap': 738875907506176},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-22',
#    'close': 4910,
#    'volume': 140128300,
#    'market_cap': 740383776571392},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-23',
#    'close': 4790,
#    'volume': 170919500,
#    'market_cap': 722288878026752},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-24',
#    'close': 4780,
#    'volume': 116037600,
#    'market_cap': 720780941852672},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-25',
#    'close': 4700,
#    'volume': 274397700,
#    'market_cap': 708717653786624},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-26',
#    'close': 4760,
#    'volume': 192267300,
#    'market_cap': 717765136613376},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-29',
#    'close': 4780,
#    'volume': 126109900,
#    'market_cap': 720699740127232},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-30',
#    'close': 4670,
#    'volume': 201835700,
#    'market_cap': 704114589696000},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-07-31',
#    'close': 4670,
#    'volume': 168490300,
#    'market_cap': 704114589696000},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-08-01',
#    'close': 4750,
#    'volume': 169636700,
#    'market_cap': 716176535584768},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-08-02',
#    'close': 4710,
#    'volume': 113328400,
#    'market_cap': 710145596194816},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-08-05',
#    'close': 4530,
#    'volume': 329430900,
#    'market_cap': 683006234722304},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-08-06',
#    'close': 4600,
#    'volume': 238051800,
#    'market_cap': 693560445763584},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-08-07',
#    'close': 4620,
#    'volume': 125937500,
#    'market_cap': 696575915458560},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-08-08',
#    'close': 4660,
#    'volume': 131343400,
#    'market_cap': 702606854848512},
#   {'symbol': 'BBRI.JK',
#    'date': '2024-08-09',
#    'close': 4670,
#    'volume': 98730900,
#    'market_cap': 704114589696000}],
#  [{'symbol': 'BMRI.JK',
#    'date': '2024-07-10',
#    'close': 6375,
#    'volume': 59685300,
#    'market_cap': 594999804690432},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-11',
#    'close': 6400,
#    'volume': 66789800,
#    'market_cap': 597333112782848},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-12',
#    'close': 6425,
#    'volume': 136132200,
#    'market_cap': 599666420875264},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-15',
#    'close': 6350,
#    'volume': 66071800,
#    'market_cap': 592666429489152},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-16',
#    'close': 6350,
#    'volume': 64687900,
#    'market_cap': 613666470756352},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-17',
#    'close': 6450,
#    'volume': 109729800,
#    'market_cap': 613666470756352},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-18',
#    'close': 6550,
#    'volume': 132532000,
#    'market_cap': 611333095555072},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-19',
#    'close': 6525,
#    'volume': 63165500,
#    'market_cap': 608999787462656},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-22',
#    'close': 6700,
#    'volume': 110467000,
#    'market_cap': 625333078327296},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-23',
#    'close': 6625,
#    'volume': 77861700,
#    'market_cap': 618333086941184},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-24',
#    'close': 6475,
#    'volume': 63940900,
#    'market_cap': 613666470756352},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-25',
#    'close': 6575,
#    'volume': 66655400,
#    'market_cap': 613666470756352},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-26',
#    'close': 6550,
#    'volume': 76519500,
#    'market_cap': 611333095555072},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-29',
#    'close': 6475,
#    'volume': 54435300,
#    'market_cap': 611333229772800},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-30',
#    'close': 6475,
#    'volume': 86701400,
#    'market_cap': 611333229772800},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-07-31',
#    'close': 6400,
#    'volume': 99004100,
#    'market_cap': 604252170878976},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-08-01',
#    'close': 6750,
#    'volume': 163086200,
#    'market_cap': 637297179492352},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-08-02',
#    'close': 6800,
#    'volume': 167892400,
#    'market_cap': 642017885421568},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-08-05',
#    'close': 6575,
#    'volume': 184384000,
#    'market_cap': 613666470756352},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-08-06',
#    'close': 6625,
#    'volume': 95785000,
#    'market_cap': 627666453528576},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-08-07',
#    'close': 6775,
#    'volume': 84582200,
#    'market_cap': 632333069713408},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-08-08',
#    'close': 6800,
#    'volume': 81408500,
#    'market_cap': 634666444914688},
#   {'symbol': 'BMRI.JK',
#    'date': '2024-08-09',
#    'close': 6850,
#    'volume': 79710700,
#    'market_cap': 639333128208384}],
#  [{'symbol': 'EXCL.JK',
#    'date': '2024-07-10',
#    'close': 2270,
#    'volume': 17274900,
#    'market_cap': 29673211822080},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-11',
#    'close': 2270,
#    'volume': 14115400,
#    'market_cap': 29673211822080},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-12',
#    'close': 2280,
#    'volume': 26838800,
#    'market_cap': 29803931500544},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-15',
#    'close': 2240,
#    'volume': 12011400,
#    'market_cap': 29281054883840},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-16',
#    'close': 2240,
#    'volume': 15377100,
#    'market_cap': 29281054883840},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-17',
#    'close': 2240,
#    'volume': 14377600,
#    'market_cap': 29281054883840},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-18',
#    'close': 2240,
#    'volume': 9450200,
#    'market_cap': 29281054883840},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-19',
#    'close': 2180,
#    'volume': 23923900,
#    'market_cap': 28496741007360},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-22',
#    'close': 2200,
#    'volume': 14478300,
#    'market_cap': 29019617624064},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-23',
#    'close': 2250,
#    'volume': 20722100,
#    'market_cap': 29411774562304},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-24',
#    'close': 2210,
#    'volume': 8864100,
#    'market_cap': 28888897945600},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-25',
#    'close': 2190,
#    'volume': 10370600,
#    'market_cap': 28627460685824},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-26',
#    'close': 2180,
#    'volume': 13159800,
#    'market_cap': 28496741007360},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-29',
#    'close': 2170,
#    'volume': 11877000,
#    'market_cap': 28366021328896},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-30',
#    'close': 2170,
#    'volume': 9638500,
#    'market_cap': 28366021328896},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-07-31',
#    'close': 2170,
#    'volume': 13824100,
#    'market_cap': 28235303747584},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-08-01',
#    'close': 2170,
#    'volume': 9289100,
#    'market_cap': 28104584069120},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-08-02',
#    'close': 2170,
#    'volume': 17463200,
#    'market_cap': 28366021328896},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-08-05',
#    'close': 2080,
#    'volume': 34132200,
#    'market_cap': 28104584069120},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-08-06',
#    'close': 2190,
#    'volume': 27207800,
#    'market_cap': 28627460685824},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-08-07',
#    'close': 2170,
#    'volume': 22667000,
#    'market_cap': 28366021328896},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-08-08',
#    'close': 2140,
#    'volume': 13277100,
#    'market_cap': 27973864390656},
#   {'symbol': 'EXCL.JK',
#    'date': '2024-08-09',
#    'close': 2160,
#    'volume': 10220500,
#    'market_cap': 28627460685824}],
#  [{'symbol': 'INTP.JK',
#    'date': '2024-07-10',
#    'close': 7325,
#    'volume': 8035800,
#    'market_cap': 25132588335104},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-11',
#    'close': 7400,
#    'volume': 5143600,
#    'market_cap': 25389917274112},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-12',
#    'close': 7500,
#    'volume': 597000,
#    'market_cap': 25733023924224},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-15',
#    'close': 7375,
#    'volume': 1384300,
#    'market_cap': 25304141660160},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-16',
#    'close': 7350,
#    'volume': 2343700,
#    'market_cap': 25218363949056},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-17',
#    'close': 7350,
#    'volume': 1005300,
#    'market_cap': 25218363949056},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-18',
#    'close': 7350,
#    'volume': 2287700,
#    'market_cap': 25218363949056},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-19',
#    'close': 7350,
#    'volume': 3043800,
#    'market_cap': 25218363949056},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-22',
#    'close': 7250,
#    'volume': 865400,
#    'market_cap': 24875257298944},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-23',
#    'close': 7250,
#    'volume': 4153000,
#    'market_cap': 24875257298944},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-24',
#    'close': 7275,
#    'volume': 818300,
#    'market_cap': 24961032912896},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-25',
#    'close': 7325,
#    'volume': 2989100,
#    'market_cap': 25132588335104},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-26',
#    'close': 7275,
#    'volume': 1539000,
#    'market_cap': 24961032912896},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-29',
#    'close': 7200,
#    'volume': 2399900,
#    'market_cap': 24703703973888},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-30',
#    'close': 7225,
#    'volume': 2474300,
#    'market_cap': 25047704010752},
#   {'symbol': 'INTP.JK',
#    'date': '2024-07-31',
#    'close': 7250,
#    'volume': 1007100,
#    'market_cap': 25134373011456},
#   {'symbol': 'INTP.JK',
#    'date': '2024-08-01',
#    'close': 7250,
#    'volume': 2364700,
#    'market_cap': 25134373011456},
#   {'symbol': 'INTP.JK',
#    'date': '2024-08-02',
#    'close': 7225,
#    'volume': 1655400,
#    'market_cap': 24482271985664},
#   {'symbol': 'INTP.JK',
#    'date': '2024-08-05',
#    'close': 7200,
#    'volume': 4364100,
#    'market_cap': 24397559627776},
#   {'symbol': 'INTP.JK',
#    'date': '2024-08-06',
#    'close': 7125,
#    'volume': 4796600,
#    'market_cap': 24143418359808},
#   {'symbol': 'INTP.JK',
#    'date': '2024-08-07',
#    'close': 7025,
#    'volume': 1412300,
#    'market_cap': 23804562636800},
#   {'symbol': 'INTP.JK',
#    'date': '2024-08-08',
#    'close': 6900,
#    'volume': 1455400,
#    'market_cap': 23380994555904},
#   {'symbol': 'INTP.JK',
#    'date': '2024-08-09',
#    'close': 6900,
#    'volume': 1256400,
#    'market_cap': 23380994555904}],
#  [{'symbol': 'ISAT.JK',
#    'date': '2024-07-10',
#    'close': 11000,
#    'volume': 4065400,
#    'market_cap': 88689480826880},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-11',
#    'close': 11500,
#    'volume': 7183200,
#    'market_cap': 92720819339264},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-12',
#    'close': 11400,
#    'volume': 5058200,
#    'market_cap': 91914556669952},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-15',
#    'close': 11425,
#    'volume': 3188000,
#    'market_cap': 92116118142976},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-16',
#    'close': 11650,
#    'volume': 3826400,
#    'market_cap': 93930224407517},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-17',
#    'close': 11600,
#    'volume': 2361500,
#    'market_cap': 93527090397184},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-18',
#    'close': 11825,
#    'volume': 3503000,
#    'market_cap': 95341193986048},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-19',
#    'close': 11500,
#    'volume': 3524400,
#    'market_cap': 92720819339264},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-22',
#    'close': 11950,
#    'volume': 2590400,
#    'market_cap': 95341193986048},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-23',
#    'close': 11650,
#    'volume': 4224400,
#    'market_cap': 93930221731840},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-24',
#    'close': 11400,
#    'volume': 6130800,
#    'market_cap': 91914556669952},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-25',
#    'close': 11500,
#    'volume': 5637100,
#    'market_cap': 92720819339264},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-26',
#    'close': 11700,
#    'volume': 2070200,
#    'market_cap': 94333353066496},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-29',
#    'close': 11700,
#    'volume': 1327600,
#    'market_cap': 94333353066496},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-30',
#    'close': 11400,
#    'volume': 3925900,
#    'market_cap': 91914556669952},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-07-31',
#    'close': 11100,
#    'volume': 4824900,
#    'market_cap': 89495751884800},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-08-01',
#    'close': 10700,
#    'volume': 5675800,
#    'market_cap': 86270894145536},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-08-02',
#    'close': 10350,
#    'volume': 9021000,
#    'market_cap': 83448941248512},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-08-05',
#    'close': 10200,
#    'volume': 4136900,
#    'market_cap': 83045809913856},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-08-06',
#    'close': 10600,
#    'volume': 4280000,
#    'market_cap': 85464623087616},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-08-07',
#    'close': 10775,
#    'volume': 3999400,
#    'market_cap': 86875595341824},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-08-08',
#    'close': 10325,
#    'volume': 2495800,
#    'market_cap': 83247379775488},
#   {'symbol': 'ISAT.JK',
#    'date': '2024-08-09',
#    'close': 10200,
#    'volume': 2794600,
#    'market_cap': 87681866399744}],
#  [{'symbol': 'JSMR.JK',
#    'date': '2024-07-10',
#    'close': 5125,
#    'volume': 2107500,
#    'market_cap': 37196581044224},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-11',
#    'close': 5300,
#    'volume': 6528200,
#    'market_cap': 38466708570112},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-12',
#    'close': 5375,
#    'volume': 4198900,
#    'market_cap': 39011049537536},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-15',
#    'close': 5300,
#    'volume': 5487100,
#    'market_cap': 38466708570112},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-16',
#    'close': 5325,
#    'volume': 2877300,
#    'market_cap': 38648155713851},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-17',
#    'close': 5200,
#    'volume': 1982800,
#    'market_cap': 37740922011648},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-18',
#    'close': 5125,
#    'volume': 3580400,
#    'market_cap': 37196581044224},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-19',
#    'close': 5350,
#    'volume': 7087700,
#    'market_cap': 38829603946496},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-22',
#    'close': 5350,
#    'volume': 2652100,
#    'market_cap': 38829603946496},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-23',
#    'close': 5450,
#    'volume': 7592600,
#    'market_cap': 39555390504960},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-24',
#    'close': 5450,
#    'volume': 2780400,
#    'market_cap': 39555390504960},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-25',
#    'close': 5475,
#    'volume': 7953000,
#    'market_cap': 39736836096000},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-26',
#    'close': 5400,
#    'volume': 11255900,
#    'market_cap': 39192495128576},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-29',
#    'close': 5400,
#    'volume': 4282500,
#    'market_cap': 39192498613984},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-30',
#    'close': 5325,
#    'volume': 5455400,
#    'market_cap': 38648158355456},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-07-31',
#    'close': 5550,
#    'volume': 10188400,
#    'market_cap': 40281177063424},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-08-01',
#    'close': 5400,
#    'volume': 9778700,
#    'market_cap': 39192495128576},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-08-02',
#    'close': 5350,
#    'volume': 6587300,
#    'market_cap': 38829603946496},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-08-05',
#    'close': 5300,
#    'volume': 6585200,
#    'market_cap': 38466708570112},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-08-06',
#    'close': 5425,
#    'volume': 5007600,
#    'market_cap': 39373944913920},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-08-07',
#    'close': 5400,
#    'volume': 1690400,
#    'market_cap': 39192495128576},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-08-08',
#    'close': 5350,
#    'volume': 1901500,
#    'market_cap': 38829603946496},
#   {'symbol': 'JSMR.JK',
#    'date': '2024-08-09',
#    'close': 5475,
#    'volume': 4563800,
#    'market_cap': 39736836096000}],
#  [{'symbol': 'MEDC.JK',
#    'date': '2024-07-10',
#    'close': 1340,
#    'volume': 36090400,
#    'market_cap': 33533498228736},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-11',
#    'close': 1330,
#    'volume': 31917400,
#    'market_cap': 33283249274880},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-12',
#    'close': 1315,
#    'volume': 42269800,
#    'market_cap': 32907873746944},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-15',
#    'close': 1285,
#    'volume': 73814100,
#    'market_cap': 32157124788224},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-16',
#    'close': 1295,
#    'volume': 24865800,
#    'market_cap': 32407373742080},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-17',
#    'close': 1290,
#    'volume': 21498600,
#    'market_cap': 32282249265152},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-18',
#    'close': 1315,
#    'volume': 41927700,
#    'market_cap': 32907873746944},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-19',
#    'close': 1285,
#    'volume': 35247800,
#    'market_cap': 32157124788224},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-22',
#    'close': 1305,
#    'volume': 32925200,
#    'market_cap': 32657624793088},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-23',
#    'close': 1285,
#    'volume': 15362700,
#    'market_cap': 32157124788224},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-24',
#    'close': 1270,
#    'volume': 33693900,
#    'market_cap': 31781749260288},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-25',
#    'close': 1270,
#    'volume': 34621400,
#    'market_cap': 31781749260288},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-26',
#    'close': 1325,
#    'volume': 60468200,
#    'market_cap': 33158124797952},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-29',
#    'close': 1310,
#    'volume': 33916900,
#    'market_cap': 32782749270016},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-30',
#    'close': 1295,
#    'volume': 16009000,
#    'market_cap': 32407373742080},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-07-31',
#    'close': 1320,
#    'volume': 27859500,
#    'market_cap': 33032998223872},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-08-01',
#    'close': 1340,
#    'volume': 70111700,
#    'market_cap': 33533498228736},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-08-02',
#    'close': 1325,
#    'volume': 39998800,
#    'market_cap': 33212845785088},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-08-05',
#    'close': 1255,
#    'volume': 78942000,
#    'market_cap': 31458204844032},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-08-06',
#    'close': 1270,
#    'volume': 35494800,
#    'market_cap': 31834201128960},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-08-07',
#    'close': 1275,
#    'volume': 30457200,
#    'market_cap': 31959531126784},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-08-08',
#    'close': 1285,
#    'volume': 28092800,
#    'market_cap': 32210195316736},
#   {'symbol': 'MEDC.JK',
#    'date': '2024-08-09',
#    'close': 1295,
#    'volume': 24614100,
#    'market_cap': 32460857409536}],
#  [{'symbol': 'PGAS.JK',
#    'date': '2024-07-10',
#    'close': 1520,
#    'volume': 91788900,
#    'market_cap': 36847082274816},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-11',
#    'close': 1560,
#    'volume': 54170100,
#    'market_cap': 37816738250752},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-12',
#    'close': 1580,
#    'volume': 30054600,
#    'market_cap': 38301570433024},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-15',
#    'close': 1580,
#    'volume': 17056600,
#    'market_cap': 38301570433024},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-16',
#    'close': 1610,
#    'volume': 55415500,
#    'market_cap': 39028815599540},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-17',
#    'close': 1620,
#    'volume': 26276100,
#    'market_cap': 39271230603264},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-18',
#    'close': 1615,
#    'volume': 16959100,
#    'market_cap': 39150023606272},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-19',
#    'close': 1595,
#    'volume': 22147100,
#    'market_cap': 38665191424000},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-22',
#    'close': 1615,
#    'volume': 13980300,
#    'market_cap': 38907609612288},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-23',
#    'close': 1595,
#    'volume': 16005600,
#    'market_cap': 38665191424000},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-24',
#    'close': 1585,
#    'volume': 19525300,
#    'market_cap': 38422777430016},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-25',
#    'close': 1555,
#    'volume': 43484500,
#    'market_cap': 37695531253760},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-26',
#    'close': 1580,
#    'volume': 23660700,
#    'market_cap': 38301570433024},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-29',
#    'close': 1605,
#    'volume': 26796400,
#    'market_cap': 38907609612288},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-30',
#    'close': 1605,
#    'volume': 24628300,
#    'market_cap': 38907609612288},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-07-31',
#    'close': 1600,
#    'volume': 20831400,
#    'market_cap': 38786398420992},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-08-01',
#    'close': 1590,
#    'volume': 14582700,
#    'market_cap': 38907609612288},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-08-02',
#    'close': 1585,
#    'volume': 21969200,
#    'market_cap': 38422777430016},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-08-05',
#    'close': 1530,
#    'volume': 73254900,
#    'market_cap': 37453117259776},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-08-06',
#    'close': 1535,
#    'volume': 34932500,
#    'market_cap': 37210703265792},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-08-07',
#    'close': 1555,
#    'volume': 35799000,
#    'market_cap': 37695531253760},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-08-08',
#    'close': 1565,
#    'volume': 24638200,
#    'market_cap': 37937949442048},
#   {'symbol': 'PGAS.JK',
#    'date': '2024-08-09',
#    'close': 1570,
#    'volume': 29247700,
#    'market_cap': 38059156439040}],
#  [{'symbol': 'PTPP.JK',
#    'date': '2024-07-10',
#    'close': 392,
#    'volume': 84189100,
#    'market_cap': 2424653217792},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-11',
#    'close': 388,
#    'volume': 57441500,
#    'market_cap': 2399911804928},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-12',
#    'close': 416,
#    'volume': 203121300,
#    'market_cap': 2573101432832},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-15',
#    'close': 406,
#    'volume': 99375500,
#    'market_cap': 2511248031744},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-16',
#    'close': 398,
#    'volume': 51526000,
#    'market_cap': 2461765206016},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-17',
#    'close': 410,
#    'volume': 76258500,
#    'market_cap': 2535989444608},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-18',
#    'close': 408,
#    'volume': 39978600,
#    'market_cap': 2523618607104},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-19',
#    'close': 398,
#    'volume': 32799400,
#    'market_cap': 2461765206016},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-22',
#    'close': 404,
#    'volume': 44099100,
#    'market_cap': 2498877194240},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-23',
#    'close': 406,
#    'volume': 35377700,
#    'market_cap': 2511248031744},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-24',
#    'close': 378,
#    'volume': 46785600,
#    'market_cap': 2338058403840},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-25',
#    'close': 382,
#    'volume': 36279900,
#    'market_cap': 2362799816704},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-26',
#    'close': 386,
#    'volume': 24450000,
#    'market_cap': 2387541229568},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-29',
#    'close': 390,
#    'volume': 24002000,
#    'market_cap': 2412282642432},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-30',
#    'close': 378,
#    'volume': 27949400,
#    'market_cap': 2338058403840},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-07-31',
#    'close': 376,
#    'volume': 29076200,
#    'market_cap': 2325687828480},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-08-01',
#    'close': 394,
#    'volume': 114887300,
#    'market_cap': 2437023793152},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-08-02',
#    'close': 388,
#    'volume': 27349100,
#    'market_cap': 2399911804928},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-08-05',
#    'close': 362,
#    'volume': 72279400,
#    'market_cap': 2239093014528},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-08-06',
#    'close': 370,
#    'volume': 32473900,
#    'market_cap': 2288575840256},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-08-07',
#    'close': 370,
#    'volume': 32191300,
#    'market_cap': 2288575840256},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-08-08',
#    'close': 368,
#    'volume': 15613400,
#    'market_cap': 2276205002752},
#   {'symbol': 'PTPP.JK',
#    'date': '2024-08-09',
#    'close': 384,
#    'volume': 64328500,
#    'market_cap': 2375170392064}],
#  [{'symbol': 'SMGR.JK',
#    'date': '2024-07-10',
#    'close': 4050,
#    'volume': 105896800,
#    'market_cap': 27343737323520},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-11',
#    'close': 4010,
#    'volume': 52636300,
#    'market_cap': 27073676574720},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-12',
#    'close': 4090,
#    'volume': 20073800,
#    'market_cap': 27613800169472},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-15',
#    'close': 4060,
#    'volume': 23445300,
#    'market_cap': 27411253035008},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-16',
#    'close': 4060,
#    'volume': 16038800,
#    'market_cap': 27411253344170},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-17',
#    'close': 4070,
#    'volume': 13397200,
#    'market_cap': 27478768746496},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-18',
#    'close': 4080,
#    'volume': 21104000,
#    'market_cap': 27546284457984},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-19',
#    'close': 4060,
#    'volume': 15604900,
#    'market_cap': 27411253035008},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-22',
#    'close': 4120,
#    'volume': 13226200,
#    'market_cap': 27546284457984},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-23',
#    'close': 4060,
#    'volume': 15155900,
#    'market_cap': 27411253035008},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-24',
#    'close': 4060,
#    'volume': 7936900,
#    'market_cap': 27411253035008},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-25',
#    'close': 3980,
#    'volume': 31301800,
#    'market_cap': 26871129440256},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-26',
#    'close': 4010,
#    'volume': 8829600,
#    'market_cap': 27073676574720},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-29',
#    'close': 3990,
#    'volume': 12987500,
#    'market_cap': 26938645151744},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-30',
#    'close': 3900,
#    'volume': 10885100,
#    'market_cap': 26462981718016},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-07-31',
#    'close': 3910,
#    'volume': 9188200,
#    'market_cap': 26530835070976},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-08-01',
#    'close': 3850,
#    'volume': 30671900,
#    'market_cap': 26123712856064},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-08-02',
#    'close': 3860,
#    'volume': 14597400,
#    'market_cap': 26191566209024},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-08-05',
#    'close': 3780,
#    'volume': 18686600,
#    'market_cap': 26060945096704},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-08-06',
#    'close': 3790,
#    'volume': 18645000,
#    'market_cap': 25588337213440},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-08-07',
#    'close': 3780,
#    'volume': 14092800,
#    'market_cap': 25520821501952},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-08-08',
#    'close': 3750,
#    'volume': 14213100,
#    'market_cap': 25318276464640},
#   {'symbol': 'SMGR.JK',
#    'date': '2024-08-09',
#    'close': 3770,
#    'volume': 11419400,
#    'market_cap': 25790884347904}],
#  [{'symbol': 'SSIA.JK',
#    'date': '2024-07-10',
#    'close': 1070,
#    'volume': 2189500,
#    'market_cap': 4874170793984},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-11',
#    'close': 1110,
#    'volume': 6707600,
#    'market_cap': 5056382894080},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-12',
#    'close': 1095,
#    'volume': 18588800,
#    'market_cap': 4988053487616},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-15',
#    'close': 1100,
#    'volume': 9938000,
#    'market_cap': 5010829606912},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-16',
#    'close': 1070,
#    'volume': 6755800,
#    'market_cap': 4874170793984},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-17',
#    'close': 1070,
#    'volume': 5236600,
#    'market_cap': 4874170793984},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-18',
#    'close': 1075,
#    'volume': 2512900,
#    'market_cap': 4896947437568},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-19',
#    'close': 1075,
#    'volume': 3074000,
#    'market_cap': 4896947437568},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-22',
#    'close': 1080,
#    'volume': 4053500,
#    'market_cap': 4896947437568},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-23',
#    'close': 1085,
#    'volume': 3862300,
#    'market_cap': 4942500200448},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-24',
#    'close': 1080,
#    'volume': 4954100,
#    'market_cap': 4919724081152},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-25',
#    'close': 1100,
#    'volume': 5495600,
#    'market_cap': 5010829606912},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-26',
#    'close': 1100,
#    'volume': 3072300,
#    'market_cap': 5010829606912},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-29',
#    'close': 1085,
#    'volume': 3524700,
#    'market_cap': 4942500200448},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-30',
#    'close': 1100,
#    'volume': 6690500,
#    'market_cap': 5010829606912},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-07-31',
#    'close': 1100,
#    'volume': 5168100,
#    'market_cap': 5079159537664},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-08-01',
#    'close': 1100,
#    'volume': 20907500,
#    'market_cap': 5039462547456},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-08-02',
#    'close': 1100,
#    'volume': 3873600,
#    'market_cap': 5085695836160},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-08-05',
#    'close': 970,
#    'volume': 31873900,
#    'market_cap': 4785177624576},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-08-06',
#    'close': 1020,
#    'volume': 19302800,
#    'market_cap': 4715827429376},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-08-07',
#    'close': 1055,
#    'volume': 4624200,
#    'market_cap': 4877644726272},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-08-08',
#    'close': 1060,
#    'volume': 4321100,
#    'market_cap': 4900761632768},
#   {'symbol': 'SSIA.JK',
#    'date': '2024-08-09',
#    'close': 1085,
#    'volume': 4249700,
#    'market_cap': 5039462547456}],
#  [{'symbol': 'TBIG.JK',
#    'date': '2024-07-10',
#    'close': 1935,
#    'volume': 2922400,
#    'market_cap': 43801628377088},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-11',
#    'close': 1990,
#    'volume': 3923900,
#    'market_cap': 45046636216320},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-12',
#    'close': 2000,
#    'volume': 1487200,
#    'market_cap': 45273002803200},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-15',
#    'close': 1970,
#    'volume': 1840700,
#    'market_cap': 44593907236864},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-16',
#    'close': 2010,
#    'volume': 2746700,
#    'market_cap': 45499366228544},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-17',
#    'close': 1990,
#    'volume': 840000,
#    'market_cap': 45046636216320},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-18',
#    'close': 1990,
#    'volume': 2206200,
#    'market_cap': 45046636216320},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-19',
#    'close': 2000,
#    'volume': 1128100,
#    'market_cap': 45273002803200},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-22',
#    'close': 1990,
#    'volume': 407900,
#    'market_cap': 45046636216320},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-23',
#    'close': 1995,
#    'volume': 1183100,
#    'market_cap': 45159819509760},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-24',
#    'close': 1920,
#    'volume': 3043300,
#    'market_cap': 43462082691072},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-25',
#    'close': 1995,
#    'volume': 921800,
#    'market_cap': 45159819509760},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-26',
#    'close': 1990,
#    'volume': 667600,
#    'market_cap': 45046636216320},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-29',
#    'close': 1965,
#    'volume': 644000,
#    'market_cap': 44480723943424},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-30',
#    'close': 1960,
#    'volume': 363600,
#    'market_cap': 44367540649984},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-07-31',
#    'close': 2000,
#    'volume': 834800,
#    'market_cap': 45273002803200},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-08-01',
#    'close': 1990,
#    'volume': 1479100,
#    'market_cap': 45046636216320},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-08-02',
#    'close': 1990,
#    'volume': 2677000,
#    'market_cap': 45046636216320},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-08-05',
#    'close': 1975,
#    'volume': 1012200,
#    'market_cap': 44656528195584},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-08-06',
#    'close': 1955,
#    'volume': 2441300,
#    'market_cap': 44204310921216},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-08-07',
#    'close': 1920,
#    'volume': 4219100,
#    'market_cap': 43412929642496},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-08-08',
#    'close': 1920,
#    'volume': 2105200,
#    'market_cap': 43412929642496},
#   {'symbol': 'TBIG.JK',
#    'date': '2024-08-09',
#    'close': 1920,
#    'volume': 2820800,
#    'market_cap': 43412929642496}],
#  [{'symbol': 'TLKM.JK',
#    'date': '2024-07-10',
#    'close': 3160,
#    'volume': 120007400,
#    'market_cap': 313036543885312},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-11',
#    'close': 3180,
#    'volume': 126490000,
#    'market_cap': 315017798877184},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-12',
#    'close': 3220,
#    'volume': 135830300,
#    'market_cap': 318980275306496},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-15',
#    'close': 3160,
#    'volume': 100918500,
#    'market_cap': 313036543885312},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-16',
#    'close': 3100,
#    'volume': 78769700,
#    'market_cap': 307092827434567},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-17',
#    'close': 3250,
#    'volume': 167149300,
#    'market_cap': 321952157794304},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-18',
#    'close': 3210,
#    'volume': 98903500,
#    'market_cap': 317989681364992},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-19',
#    'close': 3140,
#    'volume': 138117200,
#    'market_cap': 311055322447872},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-22',
#    'close': 3100,
#    'volume': 139383000,
#    'market_cap': 309074067456000},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-23',
#    'close': 3160,
#    'volume': 74338000,
#    'market_cap': 313036543885312},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-24',
#    'close': 3060,
#    'volume': 98752100,
#    'market_cap': 303130336034816},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-25',
#    'close': 3090,
#    'volume': 67060000,
#    'market_cap': 306102218522624},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-26',
#    'close': 3100,
#    'volume': 94900300,
#    'market_cap': 307092812464128},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-29',
#    'close': 3050,
#    'volume': 90885600,
#    'market_cap': 302139708538880},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-30',
#    'close': 2880,
#    'volume': 322026200,
#    'market_cap': 285299141771264},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-07-31',
#    'close': 2880,
#    'volume': 207440800,
#    'market_cap': 289261618200576},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-08-01',
#    'close': 2880,
#    'volume': 121021800,
#    'market_cap': 283317886779392},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-08-02',
#    'close': 2850,
#    'volume': 106256400,
#    'market_cap': 282327292837888},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-08-05',
#    'close': 2790,
#    'volume': 105246400,
#    'market_cap': 279355410350080},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-08-06',
#    'close': 2790,
#    'volume': 98524200,
#    'market_cap': 276383544639488},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-08-07',
#    'close': 2820,
#    'volume': 77263000,
#    'market_cap': 279355410350080},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-08-08',
#    'close': 2850,
#    'volume': 99533000,
#    'market_cap': 282327292837888},
#   {'symbol': 'TLKM.JK',
#    'date': '2024-08-09',
#    'close': 2830,
#    'volume': 80800300,
#    'market_cap': 286289769267200}],
#  [{'symbol': 'TOWR.JK',
#    'date': '2024-07-10',
#    'close': 780,
#    'volume': 42658100,
#    'market_cap': 38843218657280},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-11',
#    'close': 785,
#    'volume': 49344400,
#    'market_cap': 39092213514240},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-12',
#    'close': 810,
#    'volume': 92135200,
#    'market_cap': 40337191993344},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-15',
#    'close': 800,
#    'volume': 35384700,
#    'market_cap': 39839198085120},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-16',
#    'close': 790,
#    'volume': 29957600,
#    'market_cap': 39341208239304},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-17',
#    'close': 795,
#    'volume': 29924800,
#    'market_cap': 39590203228160},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-18',
#    'close': 795,
#    'volume': 31316800,
#    'market_cap': 39590203228160},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-19',
#    'close': 780,
#    'volume': 44518900,
#    'market_cap': 38843218657280},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-22',
#    'close': 780,
#    'volume': 11819400,
#    'market_cap': 39341208371200},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-23',
#    'close': 795,
#    'volume': 62450300,
#    'market_cap': 39590203228160},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-24',
#    'close': 785,
#    'volume': 17662700,
#    'market_cap': 39092213514240},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-25',
#    'close': 790,
#    'volume': 23131000,
#    'market_cap': 39341208371200},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-26',
#    'close': 790,
#    'volume': 17126400,
#    'market_cap': 39341208371200},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-29',
#    'close': 785,
#    'volume': 15598100,
#    'market_cap': 39092213514240},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-30',
#    'close': 785,
#    'volume': 17564800,
#    'market_cap': 39341216759808},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-07-31',
#    'close': 795,
#    'volume': 42075900,
#    'market_cap': 39842377367552},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-08-01',
#    'close': 820,
#    'volume': 119754600,
#    'market_cap': 41095283081216},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-08-02',
#    'close': 835,
#    'volume': 117259500,
#    'market_cap': 41847023992832},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-08-05',
#    'close': 800,
#    'volume': 131326000,
#    'market_cap': 40337191993344},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-08-06',
#    'close': 815,
#    'volume': 72891200,
#    'market_cap': 40586186850304},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-08-07',
#    'close': 825,
#    'volume': 22287500,
#    'market_cap': 41084176564224},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-08-08',
#    'close': 825,
#    'volume': 48354100,
#    'market_cap': 41084176564224},
#   {'symbol': 'TOWR.JK',
#    'date': '2024-08-09',
#    'close': 835,
#    'volume': 33330800,
#    'market_cap': 40835181707264}],
#  [{'symbol': 'UNTR.JK',
#    'date': '2024-07-10',
#    'close': 23550,
#    'volume': 3284800,
#    'market_cap': 85529123094528},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-11',
#    'close': 23500,
#    'volume': 2196100,
#    'market_cap': 85347534897152},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-12',
#    'close': 23500,
#    'volume': 2252700,
#    'market_cap': 85347534897152},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-15',
#    'close': 23750,
#    'volume': 2293500,
#    'market_cap': 86255492661248},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-16',
#    'close': 23800,
#    'volume': 3031900,
#    'market_cap': 86437080858624},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-17',
#    'close': 23800,
#    'volume': 3733100,
#    'market_cap': 86437080858624},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-18',
#    'close': 24350,
#    'volume': 5230200,
#    'market_cap': 88434576195584},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-19',
#    'close': 24650,
#    'volume': 6120800,
#    'market_cap': 89524113768448},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-22',
#    'close': 25300,
#    'volume': 7633600,
#    'market_cap': 90976844513280},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-23',
#    'close': 24850,
#    'volume': 3513500,
#    'market_cap': 90250483335168},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-24',
#    'close': 24825,
#    'volume': 3332200,
#    'market_cap': 90159685042176},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-25',
#    'close': 24900,
#    'volume': 3157400,
#    'market_cap': 90432071532544},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-26',
#    'close': 24975,
#    'volume': 3073200,
#    'market_cap': 90704458022912},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-29',
#    'close': 24675,
#    'volume': 2178100,
#    'market_cap': 89614912061440},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-30',
#    'close': 25000,
#    'volume': 4417000,
#    'market_cap': 91899004190720},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-07-31',
#    'close': 25800,
#    'volume': 9902100,
#    'market_cap': 93246726340608},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-08-01',
#    'close': 25550,
#    'volume': 4227300,
#    'market_cap': 93609902735360},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-08-02',
#    'close': 25650,
#    'volume': 4665000,
#    'market_cap': 94288373350400},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-08-05',
#    'close': 24425,
#    'volume': 8787200,
#    'market_cap': 88071391412224},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-08-06',
#    'close': 24150,
#    'volume': 7129900,
#    'market_cap': 87708215017472},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-08-07',
#    'close': 24725,
#    'volume': 4726300,
#    'market_cap': 89796500258816},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-08-08',
#    'close': 24625,
#    'volume': 3126500,
#    'market_cap': 89433323864064},
#   {'symbol': 'UNTR.JK',
#    'date': '2024-08-09',
#    'close': 24700,
#    'volume': 2528100,
#    'market_cap': 91340020908032}]]

# %% [markdown]
# ## Section 3.2 - Company Report Information

# %%
company_report_sminfra18 = []

for i, x in enumerate(response_company_index.json()):

  #Define the URL for the API endpoint
  url = "https://api.sectors.app/v1/company/report/" +  response_company_index.json()[i]['symbol'] + "/"

  headers = {"Authorization": userdata.get('SECTORS_API_KEY')}

  #Make the API request
  response_company_report = requests.request("GET", url, headers=headers)

  # Append the result into target list
  company_report_sminfra18.append(response_company_report.json())

  time.sleep(1)

# %%
# Create a subset to retrieve relative information for analysis
prepared_data = []

# Looping through companies in the index
for company in company_report_sminfra18:
  current_company = {}

# Accessing relative API information
  current_company['symbol'] = company['symbol']
  current_company['company_name'] = company['company_name']
  current_company['industry'] = company['overview']['industry']
  current_company['sub_industry'] = company['overview']['sub_industry']
  current_company['sector'] = company['overview']['sector']

# For the forecast variables ("company_growth_forecasts" and "company_value_forecasts"), we can see that they have both year 2024 and 2025 forecast

# Create a function to only capture year 2025 value
  if company['future']['company_value_forecasts'] != None:
    for i, forecast in enumerate(company['future']['company_value_forecasts']):
      if forecast['estimate_year'] == 2025:
        position = i

# This code below, we can see that estimate_year has both 2024 and 2025, we only want forecast variables based on year 2025
# We also observe that the year is the same for 'company_value_forecast' and 'company_growth_forecasts'
# Meaning we just create 1 function to use one variable is enough to capture all the year to 2025 for forecasting variables
    #print(company['future']['company_value_forecasts'][0]['estimate_year'])
    #print(company['future']['company_growth_forecasts'][0]['estimate_year'])
    #print('next')


# Exception handling in case the value is empty to double secure the result

  try:
    current_company['eps_estimate'] = company['future']['company_value_forecasts'][position]['eps_estimate']
  except:
    current_company['eps_estimate'] = 0

  try:
    current_company['revenue_estimate'] = company['future']['company_value_forecasts'][position]['revenue_estimate']
  except:
    current_company['revenue_estimate'] = 0

  try:
    current_company['eps_growth'] = company['future']['company_growth_forecasts'][position]['eps_growth']
  except:
    current_company['eps_growth'] = 0

  try:
    current_company['revenue_growth'] = company['future']['company_growth_forecasts'][position]['revenue_growth']
  except:
    current_company['revenue_growth'] = 0

  try:
    current_company['total_dividends'] = company['dividend']['annual_yield'][0]['total']
  except:
    current_company['total_dividends'] = 0

  try:
    current_company['avg_yield_dividends'] = company['dividend']['dividend_yield_avg']['avg_yield']
  except:
    current_company['avg_yield_dividends'] = 0

  prepared_data.append(current_company)

prepared_data
# Out:
# [{'symbol': 'ADHI.JK',
#   'company_name': 'PT Adhi Karya (Persero) Tbk.',
#   'industry': 'Heavy Constructions & Civil Engineering',
#   'sub_industry': 'Heavy Constructions & Civil Engineering',
#   'sector': 'Infrastructures',
#   'eps_estimate': 0,
#   'revenue_estimate': 15655500000000,
#   'eps_growth': -1,
#   'revenue_growth': -0.220071482804073,
#   'total_dividends': 17.0694,
#   'avg_yield_dividends': 0.00909244380891323},
#  {'symbol': 'AKRA.JK',
#   'company_name': 'PT AKR Corporindo Tbk.',
#   'industry': 'Oil & Gas',
#   'sub_industry': 'Oil & Gas Storage & Distribution',
#   'sector': 'Energy',
#   'eps_estimate': 158.97,
#   'revenue_estimate': 45464400000000,
#   'eps_growth': 0.128497644987348,
#   'revenue_growth': 0.080249278422712,
#   'total_dividends': 125,
#   'avg_yield_dividends': 0.0483752990141511},
#  {'symbol': 'BBNI.JK',
#   'company_name': 'PT Bank Negara Indonesia (Persero) Tbk',
#   'industry': 'Banks',
#   'sub_industry': 'Banks',
#   'sector': 'Financials',
#   'eps_estimate': 679.11,
#   'revenue_estimate': 71617800000000,
#   'eps_growth': 0.210047774618842,
#   'revenue_growth': 0.162937331535753,
#   'total_dividends': 280.495,
#   'avg_yield_dividends': 0.0517167726531625},
#  {'symbol': 'BBRI.JK',
#   'company_name': 'PT Bank Rakyat Indonesia (Persero) Tbk',
#   'industry': 'Banks',
#   'sub_industry': 'Banks',
#   'sector': 'Financials',
#   'eps_estimate': 451.37,
#   'revenue_estimate': 213801000000000,
#   'eps_growth': 0.133420504682536,
#   'revenue_growth': 0.284275264842541,
#   'total_dividends': 319,
#   'avg_yield_dividends': 0.0377051925286651},
#  {'symbol': 'BMRI.JK',
#   'company_name': 'PT Bank Mandiri (Persero) Tbk',
#   'industry': 'Banks',
#   'sub_industry': 'Banks',
#   'sector': 'Financials',
#   'eps_estimate': 657.58,
#   'revenue_estimate': 161727000000000,
#   'eps_growth': 0.114676156918109,
#   'revenue_growth': 0.312340707462218,
#   'total_dividends': 353.958,
#   'avg_yield_dividends': 0.043529000878334},
#  {'symbol': 'EXCL.JK',
#   'company_name': 'PT XL Axiata Tbk',
#   'industry': 'Wireless Telecommunication Services',
#   'sub_industry': 'Wireless Telecommunication Services',
#   'sector': 'Infrastructures',
#   'eps_estimate': 163.4,
#   'revenue_estimate': 36726100000000,
#   'eps_growth': 0.680381983628672,
#   'revenue_growth': 0.136234153566179,
#   'total_dividends': 42,
#   'avg_yield_dividends': 0.011895396001637},
#  {'symbol': 'INTP.JK',
#   'company_name': 'Indocement Tunggal Prakarsa Tbk',
#   'industry': 'Construction Materials',
#   'sub_industry': 'Construction Materials',
#   'sector': 'Basic Materials',
#   'eps_estimate': 520.15,
#   'revenue_estimate': 19834300000000,
#   'eps_growth': -0.0849079498610495,
#   'revenue_growth': 0.104989950838329,
#   'total_dividends': 160,
#   'avg_yield_dividends': 0.0379668477922678},
#  {'symbol': 'ISAT.JK',
#   'company_name': 'PT Indosat Tbk',
#   'industry': 'Wireless Telecommunication Services',
#   'sub_industry': 'Wireless Telecommunication Services',
#   'sector': 'Infrastructures',
#   'eps_estimate': 804.29,
#   'revenue_estimate': 58606500000000,
#   'eps_growth': 0.439008013491739,
#   'revenue_growth': 0.144015096825843,
#   'total_dividends': 255.7,
#   'avg_yield_dividends': 0.0401271820068359},
#  {'symbol': 'JSMR.JK',
#   'company_name': 'PT Jasa Marga Tbk',
#   'industry': 'Transport Infrastructure Operator',
#   'sub_industry': 'Highways & Railtracks',
#   'sector': 'Infrastructures',
#   'eps_estimate': 412.83,
#   'revenue_estimate': 18012300000000,
#   'eps_growth': -0.558954239095396,
#   'revenue_growth': -0.155090119639629,
#   'total_dividends': 75.6939,
#   'avg_yield_dividends': 0.00636524613946676},
#  {'symbol': 'MEDC.JK',
#   'company_name': 'PT Medco Energi Internasional Tbk',
#   'industry': 'Oil & Gas',
#   'sub_industry': 'Oil & Gas Production & Refinery',
#   'sector': 'Energy',
#   'eps_estimate': 0,
#   'revenue_estimate': 0,
#   'eps_growth': 0,
#   'revenue_growth': 0,
#   'total_dividends': 38.7888,
#   'avg_yield_dividends': 0.0164257543161511},
#  {'symbol': 'PGAS.JK',
#   'company_name': 'PT Perusahaan Gas Negara Tbk.',
#   'industry': 'Oil & Gas',
#   'sub_industry': 'Oil & Gas Storage & Distribution',
#   'sector': 'Energy',
#   'eps_estimate': 211.6,
#   'revenue_estimate': 58229200000000,
#   'eps_growth': 0.190791463560484,
#   'revenue_growth': 0.0309451120764361,
#   'total_dividends': 141.054,
#   'avg_yield_dividends': 0.0477137375622988},
#  {'symbol': 'PTPP.JK',
#   'company_name': 'PP (Persero) Tbk',
#   'industry': 'Heavy Constructions & Civil Engineering',
#   'sub_industry': 'Heavy Constructions & Civil Engineering',
#   'sector': 'Infrastructures',
#   'eps_estimate': 0,
#   'revenue_estimate': 25903000000000,
#   'eps_growth': -1,
#   'revenue_growth': 0.295543484289943,
#   'total_dividends': 33.842,
#   'avg_yield_dividends': 0.0114528350532055},
#  {'symbol': 'SMGR.JK',
#   'company_name': 'Semen Indonesia (Persero) Tbk',
#   'industry': 'Construction Materials',
#   'sub_industry': 'Construction Materials',
#   'sector': 'Basic Materials',
#   'eps_estimate': 390.38,
#   'revenue_estimate': 41187700000000,
#   'eps_growth': 0.214314626055841,
#   'revenue_growth': 0.0656209768556656,
#   'total_dividends': 245.19,
#   'avg_yield_dividends': 0.0204733341000974},
#  {'symbol': 'SSIA.JK',
#   'company_name': 'PT Surya Semesta Internusa Tbk',
#   'industry': 'Heavy Constructions & Civil Engineering',
#   'sub_industry': 'Heavy Constructions & Civil Engineering',
#   'sector': 'Infrastructures',
#   'eps_estimate': 94.98,
#   'revenue_estimate': 5564360000000,
#   'eps_growth': 1.44788190848669,
#   'revenue_growth': 0.226263662186343,
#   'total_dividends': 5,
#   'avg_yield_dividends': 0.00422613676637411},
#  {'symbol': 'TBIG.JK',
#   'company_name': 'PT Tower Bersama Infrastructure Tbk',
#   'industry': 'Wireless Telecommunication Services',
#   'sub_industry': 'Wireless Telecommunication Services',
#   'sector': 'Infrastructures',
#   'eps_estimate': 75.72,
#   'revenue_estimate': 7076440000000,
#   'eps_growth': None,
#   'revenue_growth': 0.0656254023517294,
#   'total_dividends': 60.3455,
#   'avg_yield_dividends': 0.0212685994803905},
#  {'symbol': 'TLKM.JK',
#   'company_name': 'PT Telkom Indonesia (Persero) Tbk',
#   'industry': 'Telecommunication Service',
#   'sub_industry': 'Integrated Telecommunication Service',
#   'sector': 'Infrastructures',
#   'eps_estimate': 281.35,
#   'revenue_estimate': 161171000000000,
#   'eps_growth': 0.140997881239521,
#   'revenue_growth': 0.0801187540210165,
#   'total_dividends': 167.599,
#   'avg_yield_dividends': 0.037667010165751},
#  {'symbol': 'TOWR.JK',
#   'company_name': 'Sarana Menara Nusantara Tbk',
#   'industry': 'Wireless Telecommunication Services',
#   'sub_industry': 'Wireless Telecommunication Services',
#   'sector': 'Infrastructures',
#   'eps_estimate': 71.69,
#   'revenue_estimate': 12786000000000,
#   'eps_growth': None,
#   'revenue_growth': 0.0890650998756851,
#   'total_dividends': 24.1,
#   'avg_yield_dividends': 0.0254231836646795},
#  {'symbol': 'UNTR.JK',
#   'company_name': 'United Tractors Tbk',
#   'industry': 'Machinery',
#   'sub_industry': 'Construction Machinery & Heavy Vehicles',
#   'sector': 'Industrials',
#   'eps_estimate': 4274.33,
#   'revenue_estimate': 116960000000000,
#   'eps_growth': None,
#   'revenue_growth': -0.0903948432978027,
#   'total_dividends': 1569,
#   'avg_yield_dividends': 0.0932280221953988}]

# %% [markdown]
# # Section 4 - Which Stock to choose?

# %% [markdown]
# ## Section 4.1 - Data Preprocessing
#
# **How to select stocks**?
#
# For our client Indra, who’s focused on stocks from the SMInfra18 index and doesn't want to invest in the ente it’s time to carefully select the right stocks.
#
# Several key economic factors should guide stock selection from an index:
#
# * Diversification by Industry and Sector: Ensuring exposure across different sectors to reduce risk.
# * Diversification by Correlation and Returns: Selecting stocks that offer varied returns and are not too closely correlated.
# * Company Growth and Dividend Information: Choosing companies with strong growth potential and reliable dividend payouts.
#
# Other factors, like recent projects, mergers, acquisitions, and broader macroeconomic or geopolitical policies, are also worth considering, though we won’t delve into them here.
#
# In this section, we will employ a range of data analysis techniques, along with our expertise in stock selection, to identify two suitable stocks from a pool of 18 for our client, Indra, to invest in.

# %% [markdown]
# **Step 1: Create a Dataframe for historical stock performance**

# %%
# Import all useful libraries
import numpy as np
import pandas as pd

# %%
# Flatten the list of lists into a single list of dictionaries
flattened_data = [item for sublist in history_sminfra18 for item in sublist]

# Convert to a pandas DataFrame
df_history_sminfra18 = pd.DataFrame(flattened_data)

# Ensure 'date' is in datetime format
df_history_sminfra18['date'] = pd.to_datetime(df_history_sminfra18['date'])

# Enforce in case any column needs conversion (e.g., 'close', 'volume', 'market_cap')
df_history_sminfra18['close'] = pd.to_numeric(df_history_sminfra18['close'], errors='coerce')
df_history_sminfra18['volume'] = pd.to_numeric(df_history_sminfra18['volume'], errors='coerce')
df_history_sminfra18['market_cap'] = pd.to_numeric(df_history_sminfra18['market_cap'], errors='coerce')

# Check for the first few rows to ensure everything is correct
print(df_history_sminfra18)
# Out:
#       symbol       date  close     volume      market_cap
# 0    ADHI.JK 2024-07-10    250   80145800   2101902442496
# 1    ADHI.JK 2024-07-11    248   37656100   2085087215616
# 2    ADHI.JK 2024-07-12    262  138657900   2202793672704
# 3    ADHI.JK 2024-07-15    256   49577700   2152348123136
# 4    ADHI.JK 2024-07-16    248   29521600   2085087257962
# ..       ...        ...    ...        ...             ...
# 409  UNTR.JK 2024-08-05  24425    8787200  88071391412224
# 410  UNTR.JK 2024-08-06  24150    7129900  87708215017472
# 411  UNTR.JK 2024-08-07  24725    4726300  89796500258816
# 412  UNTR.JK 2024-08-08  24625    3126500  89433323864064
# 413  UNTR.JK 2024-08-09  24700    2528100  91340020908032
#
# [414 rows x 5 columns]

# %%
# We aim to have all the stock price evolution in the past 90 days in one dataframe

#Pivot the DataFrame so that the 'symbol' becomes the column names and 'date' becomes the index
df_pivot_history_sminfra18 = df_history_sminfra18.pivot_table(index='date', columns='symbol', values='close')
df_pivot_history_sminfra18.head()
# Out:
# symbol      ADHI.JK  AKRA.JK  BBNI.JK  BBRI.JK  BMRI.JK  EXCL.JK  INTP.JK  \
# date
# 2024-07-10    250.0   1510.0   4820.0   4850.0   6375.0   2270.0   7325.0
# 2024-07-11    248.0   1505.0   4870.0   4840.0   6400.0   2270.0   7400.0
# 2024-07-12    262.0   1500.0   5025.0   4900.0   6425.0   2280.0   7500.0
# 2024-07-15    256.0   1505.0   5025.0   4820.0   6350.0   2240.0   7375.0
# 2024-07-16    248.0   1505.0   4980.0   4730.0   6350.0   2240.0   7350.0
#
# symbol      ISAT.JK  JSMR.JK  MEDC.JK  PGAS.JK  PTPP.JK  SMGR.JK  SSIA.JK  \
# date
# 2024-07-10  11000.0   5125.0   1340.0   1520.0    392.0   4050.0   1070.0
# 2024-07-11  11500.0   5300.0   1330.0   1560.0    388.0   4010.0   1110.0
# 2024-07-12  11400.0   5375.0   1315.0   1580.0    416.0   4090.0   1095.0
# 2024-07-15  11425.0   5300.0   1285.0   1580.0    406.0   4060.0   1100.0
# 2024-07-16  11650.0   5325.0   1295.0   1610.0    398.0   4060.0   1070.0
#
# symbol      TBIG.JK  TLKM.JK  TOWR.JK  UNTR.JK
# date
# 2024-07-10   1935.0   3160.0    780.0  23550.0
# 2024-07-11   1990.0   3180.0    785.0  23500.0
# 2024-07-12   2000.0   3220.0    810.0  23500.0
# 2024-07-15   1970.0   3160.0    800.0  23750.0
# 2024-07-16   2010.0   3100.0    790.0  23800.0

# %%
#Save the DataFrame to a CSV file -- we need to use this for MVO analysis
#df_pivot_history_sminfra18.to_csv('stock_prices_sminfra18.csv', index=False)

# %% [markdown]
# **Step 2: Create a Dataframe for company report**

# %%
df_sminfra18_company_report = pd.DataFrame(prepared_data)
df_sminfra18_company_report
# Out:
#      symbol                            company_name  \
# 0   ADHI.JK            PT Adhi Karya (Persero) Tbk.
# 1   AKRA.JK                  PT AKR Corporindo Tbk.
# 2   BBNI.JK  PT Bank Negara Indonesia (Persero) Tbk
# 3   BBRI.JK  PT Bank Rakyat Indonesia (Persero) Tbk
# 4   BMRI.JK           PT Bank Mandiri (Persero) Tbk
# 5   EXCL.JK                        PT XL Axiata Tbk
# 6   INTP.JK         Indocement Tunggal Prakarsa Tbk
# 7   ISAT.JK                          PT Indosat Tbk
# 8   JSMR.JK                       PT Jasa Marga Tbk
# 9   MEDC.JK       PT Medco Energi Internasional Tbk
# 10  PGAS.JK           PT Perusahaan Gas Negara Tbk.
# 11  PTPP.JK                        PP (Persero) Tbk
# 12  SMGR.JK           Semen Indonesia (Persero) Tbk
# 13  SSIA.JK          PT Surya Semesta Internusa Tbk
# 14  TBIG.JK     PT Tower Bersama Infrastructure Tbk
# 15  TLKM.JK       PT Telkom Indonesia (Persero) Tbk
# 16  TOWR.JK             Sarana Menara Nusantara Tbk
# 17  UNTR.JK                     United Tractors Tbk
#
#                                    industry  \
# 0   Heavy Constructions & Civil Engineering
# 1                                 Oil & Gas
# 2                                     Banks
# 3                                     Banks
# 4                                     Banks
# 5       Wireless Telecommunication Services
# 6                    Construction Materials
# 7       Wireless Telecommunication Services
# 8         Transport Infrastructure Operator
# 9                                 Oil & Gas
# 10                                Oil & Gas
# 11  Heavy Constructions & Civil Engineering
# 12                   Construction Materials
# 13  Heavy Constructions & Civil Engineering
# 14      Wireless Telecommunication Services
# 15                Telecommunication Service
# 16      Wireless Telecommunication Services
# 17                                Machinery
#
#                                sub_industry           sector  eps_estimate  \
# 0   Heavy Constructions & Civil Engineering  Infrastructures          0.00
# 1          Oil & Gas Storage & Distribution           Energy        158.97
# 2                                     Banks       Financials        679.11
# 3                                     Banks       Financials        451.37
# 4                                     Banks       Financials        657.58
# 5       Wireless Telecommunication Services  Infrastructures        163.40
# 6                    Construction Materials  Basic Materials        520.15
# 7       Wireless Telecommunication Services  Infrastructures        804.29
# 8                     Highways & Railtracks  Infrastructures        412.83
# 9           Oil & Gas Production & Refinery           Energy          0.00
# 10         Oil & Gas Storage & Distribution           Energy        211.60
# 11  Heavy Constructions & Civil Engineering  Infrastructures          0.00
# 12                   Construction Materials  Basic Materials        390.38
# 13  Heavy Constructions & Civil Engineering  Infrastructures         94.98
# 14      Wireless Telecommunication Services  Infrastructures         75.72
# 15     Integrated Telecommunication Service  Infrastructures        281.35
# 16      Wireless Telecommunication Services  Infrastructures         71.69
# 17  Construction Machinery & Heavy Vehicles      Industrials       4274.33
#
#     revenue_estimate  eps_growth  revenue_growth  total_dividends  \
# 0     15655500000000   -1.000000       -0.220071          17.0694
# 1     45464400000000    0.128498        0.080249         125.0000
# 2     71617800000000    0.210048        0.162937         280.4950
# 3    213801000000000    0.133421        0.284275         319.0000
# 4    161727000000000    0.114676        0.312341         353.9580
# 5     36726100000000    0.680382        0.136234          42.0000
# 6     19834300000000   -0.084908        0.104990         160.0000
# 7     58606500000000    0.439008        0.144015         255.7000
# 8     18012300000000   -0.558954       -0.155090          75.6939
# 9                  0    0.000000        0.000000          38.7888
# 10    58229200000000    0.190791        0.030945         141.0540
# 11    25903000000000   -1.000000        0.295543          33.8420
# 12    41187700000000    0.214315        0.065621         245.1900
# 13     5564360000000    1.447882        0.226264           5.0000
# 14     7076440000000         NaN        0.065625          60.3455
# 15   161171000000000    0.140998        0.080119         167.5990
# 16    12786000000000         NaN        0.089065          24.1000
# 17   116960000000000         NaN       -0.090395        1569.0000
#
#     avg_yield_dividends
# 0              0.009092
# 1              0.048375
# 2              0.051717
# 3              0.037705
# 4              0.043529
# 5              0.011895
# 6              0.037967
# 7              0.040127
# 8              0.006365
# 9              0.016426
# 10             0.047714
# 11             0.011453
# 12             0.020473
# 13             0.004226
# 14             0.021269
# 15             0.037667
# 16             0.025423
# 17             0.093228

# %% [markdown]
# ##Section 4.2 - Exploratory Data Analysis (EDA)

# %% [markdown]
# Our goal is to select two or three stocks from a list of 18 for Indra to invest in.
#
# At the beginning of this section, we outlined three strategies:
#
# * Diversification by Industry and Sector: Conduct an overview analysis to understand the information better.
# * Diversification by Correlation: Examine the correlation matrix based on stock price evolution.
# * Company Growth and Dividend Information: Extract all relevant information beyond sector and industry, normalize the data, and assign a score to each stock.

# %% [markdown]
# **Overview of Sectors and Industries**

# %%
# Categorize stocks by industries
df_sminfra18_company_report.industry.value_counts()
# Out:
# industry
# Wireless Telecommunication Services        4
# Heavy Constructions & Civil Engineering    3
# Oil & Gas                                  3
# Banks                                      3
# Construction Materials                     2
# Transport Infrastructure Operator          1
# Telecommunication Service                  1
# Machinery                                  1
# Name: count, dtype: int64

# %%
# Categorize stocks by sectors
df_sminfra18_company_report.sector.value_counts()
# Out:
# sector
# Infrastructures    9
# Energy             3
# Financials         3
# Basic Materials    2
# Industrials        1
# Name: count, dtype: int64

# %% [markdown]
# **Correlation Matrix on stock price evolution**

# %%
# Calculate the correlation of the 18 stock prices
correlation_matrix = df_pivot_history_sminfra18.corr()
correlation_matrix
# Out:
# symbol    ADHI.JK   AKRA.JK   BBNI.JK   BBRI.JK   BMRI.JK   EXCL.JK   INTP.JK  \
# symbol
# ADHI.JK  1.000000  0.440548  0.176121  0.792844 -0.261182  0.712415  0.517972
# AKRA.JK  0.440548  1.000000  0.013912  0.641336 -0.402469  0.429436  0.618084
# BBNI.JK  0.176121  0.013912  1.000000  0.098946  0.563663 -0.260722 -0.246213
# BBRI.JK  0.792844  0.641336  0.098946  1.000000 -0.359643  0.713161  0.637736
# BMRI.JK -0.261182 -0.402469  0.563663 -0.359643  1.000000 -0.550646 -0.752018
# EXCL.JK  0.712415  0.429436 -0.260722  0.713161 -0.550646  1.000000  0.655345
# INTP.JK  0.517972  0.618084 -0.246213  0.637736 -0.752018  0.655345  1.000000
# ISAT.JK  0.532936  0.694134 -0.039457  0.694477 -0.582224  0.594062  0.667863
# JSMR.JK -0.394091 -0.097229  0.384454 -0.368200  0.297657 -0.369505 -0.341510
# MEDC.JK  0.335281  0.611700 -0.244485  0.480077 -0.121573  0.367539  0.297970
# PGAS.JK  0.447768  0.596141  0.442136  0.419696 -0.125511  0.178426  0.258130
# PTPP.JK  0.950095  0.580895  0.185779  0.823989 -0.327325  0.735206  0.649552
# SMGR.JK  0.698716  0.688017 -0.038304  0.849783 -0.643306  0.746402  0.807500
# SSIA.JK  0.407847  0.783818  0.098079  0.532963 -0.154024  0.461269  0.316819
# TBIG.JK  0.352944  0.519306  0.016751  0.360346 -0.357244  0.267121  0.705463
# TLKM.JK  0.774944  0.591128 -0.131523  0.835566 -0.609171  0.807986  0.765074
# TOWR.JK -0.186543 -0.502401  0.368386 -0.485551  0.726373 -0.348171 -0.611388
# UNTR.JK -0.441148  0.190397  0.489077 -0.267960  0.544913 -0.604012 -0.371648
#
# symbol    ISAT.JK   JSMR.JK   MEDC.JK   PGAS.JK   PTPP.JK   SMGR.JK   SSIA.JK  \
# symbol
# ADHI.JK  0.532936 -0.394091  0.335281  0.447768  0.950095  0.698716  0.407847
# AKRA.JK  0.694134 -0.097229  0.611700  0.596141  0.580895  0.688017  0.783818
# BBNI.JK -0.039457  0.384454 -0.244485  0.442136  0.185779 -0.038304  0.098079
# BBRI.JK  0.694477 -0.368200  0.480077  0.419696  0.823989  0.849783  0.532963
# BMRI.JK -0.582224  0.297657 -0.121573 -0.125511 -0.327325 -0.643306 -0.154024
# EXCL.JK  0.594062 -0.369505  0.367539  0.178426  0.735206  0.746402  0.461269
# INTP.JK  0.667863 -0.341510  0.297970  0.258130  0.649552  0.807500  0.316819
# ISAT.JK  1.000000 -0.177365  0.156893  0.599644  0.636503  0.885277  0.450633
# JSMR.JK -0.177365  1.000000 -0.240082  0.006762 -0.366996 -0.333941  0.176441
# MEDC.JK  0.156893 -0.240082  1.000000  0.192637  0.379665  0.240347  0.591074
# PGAS.JK  0.599644  0.006762  0.192637  1.000000  0.566842  0.481073  0.475449
# PTPP.JK  0.636503 -0.366996  0.379665  0.566842  1.000000  0.794886  0.465765
# SMGR.JK  0.885277 -0.333941  0.240347  0.481073  0.794886  1.000000  0.414845
# SSIA.JK  0.450633  0.176441  0.591074  0.475449  0.465765  0.414845  1.000000
# TBIG.JK  0.505148 -0.040218  0.283598  0.457988  0.540931  0.502195  0.257534
# TLKM.JK  0.812868 -0.440506  0.248319  0.360695  0.813958  0.933356  0.403118
# TOWR.JK -0.778048  0.252760 -0.045727 -0.235107 -0.264580 -0.731329 -0.123480
# UNTR.JK -0.179367  0.565606  0.071482  0.280764 -0.318769 -0.331828  0.192893
#
# symbol    TBIG.JK   TLKM.JK   TOWR.JK   UNTR.JK
# symbol
# ADHI.JK  0.352944  0.774944 -0.186543 -0.441148
# AKRA.JK  0.519306  0.591128 -0.502401  0.190397
# BBNI.JK  0.016751 -0.131523  0.368386  0.489077
# BBRI.JK  0.360346  0.835566 -0.485551 -0.267960
# BMRI.JK -0.357244 -0.609171  0.726373  0.544913
# EXCL.JK  0.267121  0.807986 -0.348171 -0.604012
# INTP.JK  0.705463  0.765074 -0.611388 -0.371648
# ISAT.JK  0.505148  0.812868 -0.778048 -0.179367
# JSMR.JK -0.040218 -0.440506  0.252760  0.565606
# MEDC.JK  0.283598  0.248319 -0.045727  0.071482
# PGAS.JK  0.457988  0.360695 -0.235107  0.280764
# PTPP.JK  0.540931  0.813958 -0.264580 -0.318769
# SMGR.JK  0.502195  0.933356 -0.731329 -0.331828
# SSIA.JK  0.257534  0.403118 -0.123480  0.192893
# TBIG.JK  1.000000  0.448131 -0.342704  0.047037
# TLKM.JK  0.448131  1.000000 -0.624552 -0.518588
# TOWR.JK -0.342704 -0.624552  1.000000  0.211275
# UNTR.JK  0.047037 -0.518588  0.211275  1.000000

# %% [markdown]
# ## Section 4.3 - Normalization & Scoring
#
# We will extract all relevant columns (excluding those related to sectors and industries) from the `df_sminfra18_company_report` to evaluate the growth potential and dividend information for the 18 companies. Based on this analysis, we will assign scores to each company to identify the top candidates. Subsequently, we will validate our selections through diversification considerations concerning industry and sector, as well as correlation analysis.

# %%
# Import library for normalization
from sklearn.preprocessing import MinMaxScaler

# %%
# Extract useful information for normalization analysis
columns_of_interest = ['symbol', 'eps_growth', 'avg_yield_dividends', 'revenue_growth', 'revenue_estimate']
df_sminfra18_company_report_norm = df_sminfra18_company_report[columns_of_interest]
df_sminfra18_company_report_norm
# Out:
#      symbol  eps_growth  avg_yield_dividends  revenue_growth  revenue_estimate
# 0   ADHI.JK   -1.000000             0.009092       -0.220071    15655500000000
# 1   AKRA.JK    0.128498             0.048375        0.080249    45464400000000
# 2   BBNI.JK    0.210048             0.051717        0.162937    71617800000000
# 3   BBRI.JK    0.133421             0.037705        0.284275   213801000000000
# 4   BMRI.JK    0.114676             0.043529        0.312341   161727000000000
# 5   EXCL.JK    0.680382             0.011895        0.136234    36726100000000
# 6   INTP.JK   -0.084908             0.037967        0.104990    19834300000000
# 7   ISAT.JK    0.439008             0.040127        0.144015    58606500000000
# 8   JSMR.JK   -0.558954             0.006365       -0.155090    18012300000000
# 9   MEDC.JK    0.000000             0.016426        0.000000                 0
# 10  PGAS.JK    0.190791             0.047714        0.030945    58229200000000
# 11  PTPP.JK   -1.000000             0.011453        0.295543    25903000000000
# 12  SMGR.JK    0.214315             0.020473        0.065621    41187700000000
# 13  SSIA.JK    1.447882             0.004226        0.226264     5564360000000
# 14  TBIG.JK         NaN             0.021269        0.065625     7076440000000
# 15  TLKM.JK    0.140998             0.037667        0.080119   161171000000000
# 16  TOWR.JK         NaN             0.025423        0.089065    12786000000000
# 17  UNTR.JK         NaN             0.093228       -0.090395   116960000000000

# %%
# Check missing data
df_sminfra18_company_report_norm.isnull().sum()
# Out:
# symbol                 0
# eps_growth             3
# avg_yield_dividends    0
# revenue_growth         0
# revenue_estimate       0
# dtype: int64

# %%
# Impute missing data with mean - we do a simple imputation here, can also check the reason and correlation with other variables behind missing data
df_sminfra18_company_report_norm.fillna(df_sminfra18_company_report_norm.eps_growth.mean(), inplace=True)
df_sminfra18_company_report_norm.isnull().sum()
# Out:
# <ipython-input-19-83e4d5f8b276>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sminfra18_company_report_norm.fillna(df_sminfra18_company_report_norm.eps_growth.mean(), inplace=True)
# symbol                 0
# eps_growth             0
# avg_yield_dividends    0
# revenue_growth         0
# revenue_estimate       0
# dtype: int64

# %%
# Normalize the data for the metrics using MinMaxScaler
scaler = MinMaxScaler()
df_sminfra18_company_report_norm[['eps_growth', 'avg_yield_dividends', 'revenue_growth', 'revenue_estimate']] = scaler.fit_transform(df_sminfra18_company_report_norm[['eps_growth', 'avg_yield_dividends', 'revenue_growth', 'revenue_estimate']])
# Out:
# <ipython-input-20-21481d862f89>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_sminfra18_company_report_norm[['eps_growth', 'avg_yield_dividends', 'revenue_growth', 'revenue_estimate']] = scaler.fit_transform(df_sminfra18_company_report_norm[['eps_growth', 'avg_yield_dividends', 'revenue_growth', 'revenue_estimate']])

# %%
# Calculate the score by summing the normalized scores for all metrics
df_sminfra18_company_report_norm['score'] = df_sminfra18_company_report_norm.iloc[:, 1:5].sum(axis=1)

# Reorder columns to place 'score' as the third column, after 'symbol' and before 'eps_growth'
columns = list(df_sminfra18_company_report_norm.columns)
columns.insert(1, columns.pop(columns.index('score')))
df_sminfra18_company_report_norm = df_sminfra18_company_report_norm[columns]

# Display the DataFrame
df_sminfra18_company_report_norm
# Out:
#      symbol     score  eps_growth  avg_yield_dividends  revenue_growth  \
# 0   BBRI.JK  4.572937    0.463021             0.376161        0.947286
# 1   BMRI.JK  4.550356    0.455364             0.441596        1.000000
# 2   UNTR.JK  3.908740    0.437280             1.000000        0.243564
# 3   TLKM.JK  3.565195    0.466116             0.375732        0.563831
# 4   BBNI.JK  3.829574    0.494324             0.533591        0.719384
# 5   ISAT.JK  3.624269    0.587858             0.403374        0.683843
# 6   SSIA.JK  3.702678    1.000000             0.000000        0.838326
# 7   AKRA.JK  3.254914    0.461010             0.496047        0.564076
# 8   PGAS.JK  3.165438    0.486458             0.488614        0.471470
# 9   EXCL.JK  3.055501    0.686464             0.086170        0.669229
# 10  INTP.JK  2.819722    0.373830             0.379101        0.610545
# 11  SMGR.JK  2.623078    0.496067             0.182549        0.536600
# 12  TOWR.JK  2.571960    0.437280             0.238164        0.580634
# 13  TBIG.JK  2.363844    0.437280             0.191484        0.536608
# 14  PTPP.JK  2.220450    0.000000             0.081197        0.968451
# 15  MEDC.JK  1.917872    0.408516             0.137071        0.413348
# 16  JSMR.JK  0.736767    0.180174             0.024034        0.122051
# 17  ADHI.JK  0.182578    0.000000             0.054676        0.000000
#
#     revenue_estimate
# 0           1.000000
# 1           0.756437
# 2           0.547051
# 3           0.753837
# 4           0.334974
# 5           0.274117
# 6           0.026026
# 7           0.212648
# 8           0.272352
# 9           0.171777
# 10          0.092770
# 11          0.192645
# 12          0.059803
# 13          0.033098
# 14          0.121155
# 15          0.000000
# 16          0.084248
# 17          0.073225

# %%
# Sort the companies by total score
df_sminfra18_company_report_norm = df_sminfra18_company_report_norm.sort_values(by='score', ascending=False).reset_index(drop=True)
df_sminfra18_company_report_norm
# Out:
#      symbol  eps_growth  avg_yield_dividends  revenue_growth  \
# 0   BBRI.JK    0.463021             0.376161        0.947286
# 1   BMRI.JK    0.455364             0.441596        1.000000
# 2   UNTR.JK    0.437280             1.000000        0.243564
# 3   TLKM.JK    0.466116             0.375732        0.563831
# 4   BBNI.JK    0.494324             0.533591        0.719384
# 5   ISAT.JK    0.587858             0.403374        0.683843
# 6   SSIA.JK    1.000000             0.000000        0.838326
# 7   AKRA.JK    0.461010             0.496047        0.564076
# 8   PGAS.JK    0.486458             0.488614        0.471470
# 9   EXCL.JK    0.686464             0.086170        0.669229
# 10  INTP.JK    0.373830             0.379101        0.610545
# 11  SMGR.JK    0.496067             0.182549        0.536600
# 12  TOWR.JK    0.437280             0.238164        0.580634
# 13  TBIG.JK    0.437280             0.191484        0.536608
# 14  PTPP.JK    0.000000             0.081197        0.968451
# 15  MEDC.JK    0.408516             0.137071        0.413348
# 16  JSMR.JK    0.180174             0.024034        0.122051
# 17  ADHI.JK    0.000000             0.054676        0.000000
#
#     revenue_estimate     score
# 0           1.000000  2.786468
# 1           0.756437  2.653396
# 2           0.547051  2.227895
# 3           0.753837  2.159516
# 4           0.334974  2.082274
# 5           0.274117  1.949193
# 6           0.026026  1.864352
# 7           0.212648  1.733781
# 8           0.272352  1.718895
# 9           0.171777  1.613639
# 10          0.092770  1.456246
# 11          0.192645  1.407862
# 12          0.059803  1.315881
# 13          0.033098  1.198471
# 14          0.121155  1.170803
# 15          0.000000  0.958936
# 16          0.084248  0.410508
# 17          0.073225  0.127901

# %%
# Pick the top 5 companies
top_5_companies = df_sminfra18_company_report_norm.head(5)
top_5_companies
# Out:
#     symbol  eps_growth  avg_yield_dividends  revenue_growth  revenue_estimate  \
# 0  BBRI.JK    0.463021             0.376161        0.947286          1.000000
# 1  BMRI.JK    0.455364             0.441596        1.000000          0.756437
# 2  UNTR.JK    0.437280             1.000000        0.243564          0.547051
# 3  TLKM.JK    0.466116             0.375732        0.563831          0.753837
# 4  BBNI.JK    0.494324             0.533591        0.719384          0.334974
#
#       score
# 0  2.786468
# 1  2.653396
# 2  2.227895
# 3  2.159516
# 4  2.082274

# %% [markdown]
# ##Section 4.4 - Stock selection choice
#
# Based on the results from Section 4.3, we have identified the top five stock tickers that we should consider for selection, as they have received the highest scores.
#
# Next, we will implement our diversification strategy, focusing on industry and sector, as well as correlation analysis, to select two stocks from this group of five high-scoring candidates.

# %%
# Store the top 5 company symbol into a list
top_5_symbols = top_5_companies['symbol'].tolist()
top_5_symbols
# Out:
# ['BBRI.JK', 'BMRI.JK', 'UNTR.JK', 'TLKM.JK', 'BBNI.JK']

# %%
# Query the sector & industry information for the top 5 companies
top_5_info = df_sminfra18_company_report[df_sminfra18_company_report['symbol'].isin(top_5_symbols)]
top_5_info
# Out:
#      symbol                            company_name  \
# 2   BBNI.JK  PT Bank Negara Indonesia (Persero) Tbk
# 3   BBRI.JK  PT Bank Rakyat Indonesia (Persero) Tbk
# 4   BMRI.JK           PT Bank Mandiri (Persero) Tbk
# 15  TLKM.JK       PT Telkom Indonesia (Persero) Tbk
# 17  UNTR.JK                     United Tractors Tbk
#
#                      industry                             sub_industry  \
# 2                       Banks                                    Banks
# 3                       Banks                                    Banks
# 4                       Banks                                    Banks
# 15  Telecommunication Service     Integrated Telecommunication Service
# 17                  Machinery  Construction Machinery & Heavy Vehicles
#
#              sector  eps_estimate  revenue_estimate  eps_growth  \
# 2        Financials        679.11    71617800000000    0.210048
# 3        Financials        451.37   213801000000000    0.133421
# 4        Financials        657.58   161727000000000    0.114676
# 15  Infrastructures        281.35   161171000000000    0.140998
# 17      Industrials       4274.33   116960000000000         NaN
#
#     revenue_growth  total_dividends  avg_yield_dividends
# 2         0.162937          280.495             0.051717
# 3         0.284275          319.000             0.037705
# 4         0.312341          353.958             0.043529
# 15        0.080119          167.599             0.037667
# 17       -0.090395         1569.000             0.093228

# %% [markdown]
# We have three stocks are all in banking industry / financial sector. For those three tickers (BBNI.JK, BBRI.JK, BMRI.JK), we choose the ticker with the highest score - BBRI.JK.
#
# Now we have our choice: BBRI.JK, TLKM.JK, UNTR.JK.
#
# We need to confirm that their price movement doesn't have high positive correlation.

# %%
# Query the price history info for selected 3 tickers and check correlation
selected_3_symbols =  ['BBRI.JK', 'TLKM.JK', 'UNTR.JK']
selected_3_prices = df_pivot_history_sminfra18[selected_3_symbols]
correlation_matrix_selected = selected_3_prices.corr()
correlation_matrix_selected
# Out:
# symbol    BBRI.JK   TLKM.JK   UNTR.JK
# symbol
# BBRI.JK  1.000000  0.835566 -0.267960
# TLKM.JK  0.835566  1.000000 -0.518588
# UNTR.JK -0.267960 -0.518588  1.000000

# %% [markdown]
# TLKM.JK and BBRI.JK, their price has strong positive correlation! We drop one and only select BBRI.JK, since it has the highest score regarding growth potential analysis.
#
# To sum up, our final choices are two stocks: BBRI.JK & UNTR.JK.

# %%
Indra_stocks = ['BBRI.JK', 'UNTR.JK']

# %%
# Query the price info for Indra_stocks
price_Indra = df_pivot_history_sminfra18[Indra_stocks]
price_Indra
# Out:
# symbol      BBRI.JK  UNTR.JK
# date
# 2024-07-10   4850.0  23550.0
# 2024-07-11   4840.0  23500.0
# 2024-07-12   4900.0  23500.0
# 2024-07-15   4820.0  23750.0
# 2024-07-16   4730.0  23800.0
# 2024-07-17   4760.0  23800.0
# 2024-07-18   4890.0  24350.0
# 2024-07-19   4900.0  24650.0
# 2024-07-22   4910.0  25300.0
# 2024-07-23   4790.0  24850.0
# 2024-07-24   4780.0  24825.0
# 2024-07-25   4700.0  24900.0
# 2024-07-26   4760.0  24975.0
# 2024-07-29   4780.0  24675.0
# 2024-07-30   4670.0  25000.0
# 2024-07-31   4670.0  25800.0
# 2024-08-01   4750.0  25550.0
# 2024-08-02   4710.0  25650.0
# 2024-08-05   4530.0  24425.0
# 2024-08-06   4600.0  24150.0
# 2024-08-07   4620.0  24725.0
# 2024-08-08   4660.0  24625.0
# 2024-08-09   4670.0  24700.0

# %%
# Normalize prices to start from 100 for easy comparison
price_norm = price_Indra / price_Indra.iloc[0] * 100

# Calculate percentage gains from the initial price
price_gains = ((price_Indra - price_Indra.iloc[0]) / price_Indra.iloc[0]) * 100

# Plotting normalized prices and percentage gains
plt.figure(figsize=(14, 6))

# Plot normalized prices
plt.subplot(1, 2, 1)
price_norm.plot(ax=plt.gca(), title="Normalized Price Performance")
plt.ylabel('Normalized Price (Start = 100)')
plt.xlabel('Date')
plt.legend(title='Stock Symbol')
plt.grid(True)

# Plot percentage gains
plt.subplot(1, 2, 2)
price_gains.plot(ax=plt.gca(), title="Percentage Gains Over Time")
plt.ylabel('Percentage Gain (%)')
plt.xlabel('Date')
plt.legend(title='Stock Symbol')
plt.grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Section 5 - MVO with Monte Carlos Simulation

# %% [markdown]
# ## Section 5.1 - Theoretical Context

# %% [markdown]
# After understanding which stock to invest in, here are some key questions:
#
# *   How much of each stock should we hold?
# *   How to balance between risk and reward?
#
# This is where Mean-Variance Optimization (MVO) comes in. It’s a method to help us find the optimal way to allocate our capital among various stocks - find the optimal weight.
#
#
# What are the information we need?
#
# 1.	Expected Returns:
# This is the average return you expect from each stock based on historical performance.
#
#
# 2.	Risk (Volatility):	Risk is measured as the variance (or more commonly, standard deviation) of the returns. It shows how much the stock’s returns fluctuate.
#
# 3.	Covariance Between Stocks: Covariance tells us how the returns of two stocks move together. Some stocks may go up and down at the same time (positive covariance), while others may move in opposite directions (negative covariance). Covariance helps us understand how diversification can reduce risk.
#
# Step 2: Build the Model
#
# Once we have this data, the next step is to use it to construct a portfolio of stocks. The goal of the model is twofold:
#
# * Maximize Return: We want to achieve the highest possible return for a given amount of risk.
# * Minimize Risk: Alternatively, we might want to minimize risk while achieving a certain return level.
#
# Consult the mathematical model here: [link text](https://en.wikipedia.org/wiki/Modern_portfolio_theory)
#
#
# Step 3: Optimize the Portfolio through Sharp Ratio
#
# Now that the model is built, we can use it to optimize the portfolio. This means:
#
# * Maximizing Return for a Given Level of Risk: This is suitable for investors who are willing to take on some risk but want to get the highest return for that risk level.
#
# * Minimizing Risk for a Given Return: This is helpful for more conservative investors who want to reduce risk as much as possible while still achieving a certain return.
#
# This optimization results will generate an Efficient Frontier:
#
# A curve that shows the best possible portfolios in terms of risk and return. Every point on the frontier represents a portfolio that either minimizes risk for a given return or maximizes return for a given risk.
#
# The highest sharp ratio point, which lies on the efficient frontier, gives the optimal portfolio weight.
#
#
#
# **Bibliography**:
#
# Useful math for Portfolio Optimization. [link](https://www.fields.utoronto.ca/programs/scientific/09-10/finance/courses/pliska3.pdf)
#
# Understand basic concepts of mean (return), variance (risk) and how they work in investing. [link](https://smartasset.com/financial-advisor/mean-variance-optimization)
#
# Understand Mean Variance Optimization Model. [link](https://analystprep.com/study-notes/cfa-level-iii/mean-variance-optimization-an-overview/#:~:text=Mean%2Dvariance%20optimization%20(%E2%80%9CMVO,risk%2Dto%2Dreturn%20profile.)

# %% [markdown]
# ## Section 5.2 - Mean & Variance
#
# For this section, for a better illustration of the model, we will randomly generate 4 stocks from the sminfra18 to compose a portfolio to optimize.

# %%
# Import all useful libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Randomly select 4 stocks from sminfra18
sminfra18_tickers = df_pivot_history_sminfra18.columns.tolist()

selected_stocks = np.random.choice(sminfra18_tickers, size=4, replace=False)
selected_stocks
# Out:
# array(['PGAS.JK', 'UNTR.JK', 'TBIG.JK', 'TLKM.JK'], dtype='<U7')

# %%
# Query the price info for the selected stocks
prices = df_pivot_history_sminfra18[selected_stocks]
prices.head()
# Out:
# symbol      PGAS.JK  UNTR.JK  TBIG.JK  TLKM.JK
# date
# 2024-07-10   1520.0  23550.0   1935.0   3160.0
# 2024-07-11   1560.0  23500.0   1990.0   3180.0
# 2024-07-12   1580.0  23500.0   2000.0   3220.0
# 2024-07-15   1580.0  23750.0   1970.0   3160.0
# 2024-07-16   1610.0  23800.0   2010.0   3100.0

# %%
# Calculate Returns
returns = pd.DataFrame()

for stock in prices:
  returns[stock + ' Returns'] = prices[stock].pct_change().dropna()

returns.head()
# Out:
#             PGAS.JK Returns  UNTR.JK Returns  TBIG.JK Returns  TLKM.JK Returns
# date
# 2024-07-11         0.026316        -0.002123         0.028424         0.006329
# 2024-07-12         0.012821         0.000000         0.005025         0.012579
# 2024-07-15         0.000000         0.010638        -0.015000        -0.018634
# 2024-07-16         0.018987         0.002105         0.020305        -0.018987
# 2024-07-17         0.006211         0.000000        -0.009950         0.048387

# %%
# Calculate expected returns (mean) and covariance matrix
# Assuming 252 is the trading days in a year = 365 - weekends 104 - holidays 9
# We need to annualize the return and risk since MVO models are long-term orientated and long-term in economics perspectives refers to 12 months +

expected_returns = returns.mean() * 252  # Annualize by multiplying by trading days
covariance_matrix = returns.cov() * 252   # Annualize covariance

# Print the expected returns and covariance matrix
print("Expected Returns:")
print(expected_returns)
print("\nCovariance Matrix:")
print(covariance_matrix)
# Out:
# Expected Returns:
# PGAS.JK Returns    0.394443
# UNTR.JK Returns    0.582308
# TBIG.JK Returns   -0.056850
# TLKM.JK Returns   -1.207224
# dtype: float64
#
# Covariance Matrix:
#                  PGAS.JK Returns  UNTR.JK Returns  TBIG.JK Returns  \
# PGAS.JK Returns         0.048921         0.022824         0.002496
# UNTR.JK Returns         0.022824         0.074070         0.008815
# TBIG.JK Returns         0.002496         0.008815         0.067872
# TLKM.JK Returns         0.013206        -0.006651         0.018117
#
#                  TLKM.JK Returns
# PGAS.JK Returns         0.013206
# UNTR.JK Returns        -0.006651
# TBIG.JK Returns         0.018117
# TLKM.JK Returns         0.110532

# %%
# Here we can see the distribution of each stock returns
returns.hist(figsize=(8,6), bins = 50)
plt.show()

# %% [markdown]
# ##Section 5.3 Monte Carlo Simulation

# %% [markdown]
# Monte Carlo simulation is a powerful technique used in portfolio optimization to assess the potential outcomes of different investment strategies or different allocations under varying conditions. It involves generating multiple scenarios based on statistical models and random sampling.
#
# Implementing Monte Carlo simulation in Python involves combining statistical analysis, simulation, and optimization techniques to gain insights into portfolio performance under different allocations. For our analysis, we will run a simulation on different allocations of the same stocks to find the optimum allocation. A single run of the simulation is shown in the code below.

# %%
# Define Risk Free rate
# Assume RF as 6.64% as the yield of 10 year Indonesian Government bond
# Source link https://tradingeconomics.com/indonesia/government-bond-yield
rf = 0.0664

# Monte Carlo simulation
#Single Run
np.random.seed(101)
print(selected_stocks)

# Generates an array of random numbers representing initial weights for each asset in the portfolio
weights = np.array(np.random.random(4))
print('\nRandom Weights')
print(weights)

# Normalizing the randomly generated weights to ensure they sum up to 1, representing a fully invested portfolio.
print('\nRebalanced Weights')
weights = weights / np.sum(weights)
print(weights)

# Calculating the portfolio’s expected return using the weighted average of individual asset returns.
# It multiplies the annual mean returns of each asset by its respective weight and aggregates them.
print('\nPortfolio Return')
portfolio_return = np.sum(returns.mean()*252*weights)
print(portfolio_return)

# Expected Volatility (Standard Deviation): Using the formula for portfolio volatility, it calculates the square root of the dot product of weights, the covariance matrix of asset returns (multiplied by 252 for annualization), and weights transpose.
# The square root of covariance matrix is taken because square root of variance is standard deviation or volatility.
print('\nPortfolio Volatility')
portfolio_volatility = np.sqrt(np.dot(weights.T, np.dot(returns.cov()*252, weights)))
print(portfolio_volatility)

# Sharpe Ratio measures the risk-adjusted return by subtracting the risk-free rate from the portfolio return and dividing by its volatility.
print('\nPortfolio Sharpe Ratio')
sharpe_ratio = (portfolio_return - rf) / portfolio_volatility
print(sharpe_ratio)
# Out:
# ['PGAS.JK' 'UNTR.JK' 'TBIG.JK' 'TLKM.JK']
#
# Random Weights
# [0.51639863 0.57066759 0.02847423 0.17152166]
#
# Rebalanced Weights
# [0.40122278 0.44338777 0.02212343 0.13326603]
#
# Portfolio Return
# 0.25430815938385554
#
# Portfolio Volatility
# 0.18304080881645118
#
# Portfolio Sharpe Ratio
# 1.0265916141808857

# %% [markdown]
# Having seen a single run of the simulation above, let us now perform 5000 simulations of the random allocations generated to find the optimum allocation for the four stocks chosen. The portfolio performance will analyzed based on the Sharpe ratio. The Sharpe ratio gives the return delivered per unit of risk taken. The code for the simulation is shown below.

# %%
# Specify the number of simulated portfolios to generate (in our case, 5000)
num_ports = 5000

# A 2D array to store the randomly generated weights for each asset in each portfolio.
all_weights = np.zeros((num_ports, len(selected_stocks)))

# Create arrays to store portfolio returns, volatilities, and Sharpe ratios for each simulated portfolio.
ret_arr = np.zeros(num_ports)
vol_arr = np.zeros(num_ports)
sharp_arr = np.zeros(num_ports)

# Looping over each portfolio
for i in range(num_ports):

  # Generate random weights randomly assigning weights to each asset in the portfolio and rebalancing them to sum up to 1
  weights = np.array(np.random.random(4))
  weights = weights / np.sum(weights)
  all_weights[i, :] = weights

  #Expected return
  ret_arr[i] = np.sum((returns.mean() * 252 * weights))

  #Expected volatility
  vol_arr[i] = np.sqrt(np.dot(weights.T, np.dot(returns.cov() * 252, weights)))

  #Sharpe ratio
  sharp_arr[i] = (ret_arr[i] - rf) / vol_arr[i]

# %% [markdown]
# ## Section 5.4 - Sharpe Ratio
#
# Sharpe ratio measures the risk-adjusted return by subtracting the risk-free rate. We want the portfolio weight randomly generated by Monte Carlo Simulation with the highest sharp ratio.
#
# More info [link](https://www.investopedia.com/terms/s/sharperatio.asp)

# %%
# Retrieve the maximum value from the sharp_arr array
max_sr = sharp_arr.max()

# %%
# Find the index of the portfolio with the maximum Sharpe ratio in the sharp_arr array.
max_sr_index = sharp_arr.argmax()

# %%
# Retrieve the weights of the assets in the portfolio corresponding to the index 4091 in the all_weights array.
opt_weights = all_weights[max_sr_index,:]

# %%
# Retrive the optimal expected returns and volaticity
optimal_return = ret_arr[max_sr_index]
optimal_volatility = vol_arr[max_sr_index]

# %%
# Print Result
print('Max Sharpe Ratio: ', max_sr)
print('Optimal Return: ', optimal_return)
print('Optimal Volatility: ', optimal_volatility)
print('Optimal Weights: ', opt_weights)
print('Stock List: ', selected_stocks)
# Out:
# Max Sharpe Ratio:  2.0346018098713943
# Optimal Return:  0.4819911385679692
# Optimal Volatility:  0.20426165776105273
# Optimal Weights:  [0.47205837 0.51425067 0.01118475 0.00250621]
# Stock List:  ['PGAS.JK' 'UNTR.JK' 'TBIG.JK' 'TLKM.JK']

# %% [markdown]
# ##Section 5.5 - Efficient Frontier

# %% [markdown]
# The efficient frontier rates portfolios on a  coordinate plane. Plotted on the x-axis is the risk, while return is plotted on the y-axis—annualized standard deviation is typically used to measure risk, while compound annual growth rate (CAGR) is used for return.
#
# More info [link](https://www.investopedia.com/terms/e/efficientfrontier.asp)
#
# The volatility, return and sharpe ratio values for the simulation are plotted below.

# %%
plt.figure(figsize = (10,5))
plt.scatter(vol_arr, ret_arr, c = sharp_arr, cmap = 'plasma')
plt.colorbar(label = 'Sharpe Ratio')
plt.xlabel('Volatility', fontweight = 'bold')
plt.ylabel('Return', fontweight = 'bold')

plt.scatter(optimal_volatility, optimal_return, c='red', s=200, edgecolors='black', marker='*')
plt.grid(True, ls=':', lw=1)

# %% [markdown]
# The visualization can be seen above for volatility, return and sharpe ratio. The x-axis shows the volatility, y axis shows the return and the colorbar on right shows the sharpe ratio graded colorwise with dark color showing the lowest and light values showing the highest sharpe ratio. The red star shows the highest Sharpe ratio point on the plot.

# %% [markdown]
# # Section 6 - MVO with Scipy Minimized Function

# %% [markdown]
# ## Section 6.1 - Overview

# %% [markdown]
# In our next analysis method, we will optimize the same portfolio allocation mathematically using the minimize function in Scipy (a library in Python) and Sharpe ratio.
#
# Portfolio optimization using Scipy’s minimize function and the Sharpe ratio involves using mathematical optimization to find the optimal asset allocation that maximizes the Sharpe ratio—a measure of risk-adjusted returns.
#
# The basic principle is to find the Sharpe ratio for a random allocation and then multiply it by -1 to make it negative and then minimize it to obtain the allocation weights that gives the highest Sharpe ratio.

# %%
def ret_vol_sr(weights):
  weights = np.array(weights)

  # Calculate Annualized Expected Returns
  ret = np.sum(returns.mean() * weights * 252)

  # Calculate Portfolio Volaticity
  vol = np.sqrt(np.dot(weights.T, np.dot(returns.cov() * 252, weights)))

  # Calculate Sharp Ratio, Rist Free rate 6.4%
  sr = (ret - rf) / vol

  return np.array([ret, vol, sr])

# %% [markdown]
# ##Section 6.2 Scipy Minimize Function

# %%
from scipy.optimize import minimize

# %%
# This function below is designed to negate the Sharpe ratio because in optimization, the objective function is minimized by default.
# We want to maximize the Sharpe ratio, index 2, so multiplying by -1 helps flip the optimization to achieve that.
def sharp_neg(weights):
  return ret_vol_sr(weights)[2] * -1

# %%
# constraint function ensures the weight sum is 1
# In optimization, constraints are typically written such that the result equals 0
# If the sum of weights is exactly 1, then np.sum(weights) - 1 will equal 0. This satisfies the constraint that the sum of the weights must be 1.
def sum_check(weights):
  return np.sum(weights) - 1

# %%
# We want equity constraint, the function must return a value equals to 0
# Specify the equality constraint that the sum of weights must equal 1.
cons = ({'type': 'eq', 'fun': sum_check})

# Ensure that each weight lies between 0 and 1, meaning no short-selling or leverage.
bounds = ((0, 1), (0, 1), (0, 1), (0, 1))

# %%
# Initial guess for the optimization - equal weighting of 25% for each stock initially.
init_guess = [0.25, 0.25, 0.25, 0.25]

# %%
# SLSQP stands for Sequential Least Squares Quadratic Programming, which is an algorithm that can handle both equality and inequality constraints, making it well-suited for portfolio optimization problems.
# We are minimize the negative sharp ratio - maximize sharp ratio

opt_results = minimize(sharp_neg, init_guess, method = 'SLSQP', bounds = bounds, constraints = cons)

# %%
opt_results

# fun --> Returns the result for the negative sharpe ratio
# x --> Represents the optimizal weights in accordance with the stock list order
# nit --> This value indicates the number of iterations that the optimization algorithm took to converge to the optimal solution. A smaller number usually means a faster convergence
# jac --> Jacobian (or gradient) of the objective function at the optimal weights
# Out:
#  message: Optimization terminated successfully
#  success: True
#   status: 0
#      fun: -2.0678015196575585
#        x: [ 4.136e-01  5.864e-01  0.000e+00  1.062e-14]
#      nit: 6
#      jac: [-3.133e-01 -3.133e-01  5.538e-01  5.769e+00]
#     nfev: 31
#     njev: 6

# %%
# opt_results.x gives the optimized portfolio weights.
opt_results.x
# Out:
# array([4.13647417e-01, 5.86352583e-01, 0.00000000e+00, 1.06241346e-14])

# %%
#return the expected return, volatility, and Sharpe ratio for the optimized portfolio.
ret_vol_sr(opt_results.x)
# Out:
# array([0.50459828, 0.21191506, 2.06780152])

# %%
# Print Result
print('Return: ', ret_vol_sr(opt_results.x)[0])
print('Volatility: ', ret_vol_sr(opt_results.x)[1])
print('Sharpe Ratio: ', ret_vol_sr(opt_results.x)[2])
print (selected_stocks)
print ('Optimal Weights: ', opt_results.x)
# Out:
# Return:  0.5045982793617794
# Volatility:  0.21191505818911857
# Sharpe Ratio:  2.0678015196575585
# ['PGAS.JK' 'UNTR.JK' 'TBIG.JK' 'TLKM.JK']
# Optimal Weights:  [4.13647417e-01 5.86352583e-01 0.00000000e+00 1.06241346e-14]

# %% [markdown]
# ##Section 6.3 - Result Comparison

# %%
# Print Result from Monte Carlos Simulation
print ('\nResult from Monte Carlos Simulation')
print('Stock List: ', selected_stocks)
print('Optimal Weights: ', opt_weights)
print('Optimal Return: ', optimal_return)
print('Optimal Volatility: ', optimal_volatility)
print('Max Sharpe Ratio: ', max_sr)

# Print Result from Scipy Minimized Function
print ('\nResult from Scipy Minimized Function')
print ('Stock List: ', selected_stocks)
print ('Optimal Weights: ', opt_results.x)
print('Return: ', ret_vol_sr(opt_results.x)[0])
print('Volatility: ', ret_vol_sr(opt_results.x)[1])
print('Sharpe Ratio: ', ret_vol_sr(opt_results.x)[2])
# Out:
# Result from Monte Carlos Simulation
# Stock List:  ['PGAS.JK' 'UNTR.JK' 'TBIG.JK' 'TLKM.JK']
# Optimal Weights:  [0.47205837 0.51425067 0.01118475 0.00250621]
# Optimal Return:  0.4819911385679692
# Optimal Volatility:  0.20426165776105273
# Max Sharpe Ratio:  2.0346018098713943
#
# Result from Scipy Minimized Function
# Stock List:  ['PGAS.JK' 'UNTR.JK' 'TBIG.JK' 'TLKM.JK']
# Optimal Weights:  [4.13647417e-01 5.86352583e-01 0.00000000e+00 1.06241346e-14]
# Return:  0.5045982793617794
# Volatility:  0.21191505818911857
# Sharpe Ratio:  2.0678015196575585

# %%
# Draw Efficient Frontier

plt.figure(figsize = (10,5))
plt.scatter(vol_arr, ret_arr, c = sharp_arr, cmap = 'plasma')
plt.colorbar(label = 'Sharpe Ratio')
plt.xlabel('Volatility', fontweight = 'bold')
plt.ylabel('Return', fontweight = 'bold')

# Optimial point for Monte Carlos Simulation is labelled as red star
plt.scatter(optimal_volatility, optimal_return, c='red', s=200, edgecolors='black', marker='*')
plt.grid(True, ls=':', lw=1)

# Optimial point for Scipy Optimization is labelled as green star
plt.scatter(ret_vol_sr(opt_results.x)[1], ret_vol_sr(opt_results.x)[0], c='green', s=200, edgecolors='black', marker='*')

# %% [markdown]
# Summary:
#
# The Monte Carlo Simulation provides a diversified portfolio with a balanced approach to risk and return, while the Scipy Optimization approach is more aggressive, concentrating investments in fewer stocks with higher expected returns but also slightly increased volatility.
#
# Overall, the Scipy optimization yields better risk-adjusted returns (higher Sharpe ratio) and expected returns, making it a more favorable strategy in this context. However, the Monte Carlo simulation’s results reflect a more cautious approach to diversification that may suit risk-averse investors.

# %% [markdown]
# # Section 7 - Summaries and Recommendations

# %% [markdown]
# Workshop Summary
#
# This workshop explored key concepts in portfolio optimization, focusing on sector analysis, stock selection methodologies, and mean-variance optimization (MVO). The main topics included:
#
# * Understanding Sectors and Stock Indices: Selecting stock indices based on business objectives and industry trends using SectorsAPI.
# Data Collection and Exploration: Retrieving stock data from APIs and performing exploratory data analysis (EDA) to identify trends and outliers.
# * Stock Selection via Diversification Strategy: Applying EDA and normalization techniques to score companies on growth potential, dividends, and financial indicators.
# * Mean-Variance Optimization (MVO): Implementing portfolio optimization through Monte Carlo simulations and the Scipy minimized function to maximize returns for a given risk level.
#
# Stock Index Selection
#
# In this workshop, we focused on Indra’s case using a single stock index. In practice, building a robust portfolio involves selecting stocks from multiple indices, enhancing diversification across companies, regions, asset classes, and sectors to reduce risk and improve stability. Considerations include global market trends, macroeconomic conditions, and sector performance.
#
# Stock Analysis and Selection
#
# We employed a diversification strategy by normalizing the dataset and scoring companies based on key metrics. In real applications, the analysis would be more complex, incorporating:
#
# * Macroeconomic Conditions: Factors like interest rates and inflation can significantly impact stock performance.
# * Valuation Metrics: Evaluating P/E ratios, price-to-book, and free cash flow yield is critical for assessing valuations.
# * Risk Factors: Systemic and geopolitical risks should be considered.
# * Sustainability and ESG Factors: Institutional investors increasingly prioritize environmental, social, and governance criteria for long-term growth.
#
# Mean-Variance Optimization
#
# Two approaches to MVO were applied:
#
# * Monte Carlo Simulation: This method generates thousands of random portfolios to visualize the efficient frontier and calculate the Sharpe ratio. While flexible, it can be computationally expensive and may not converge on the most efficient portfolios.
# * Scipy Minimized Function: This deterministic method computes the optimal portfolio by minimizing volatility or maximizing the Sharpe ratio under specific constraints. It is faster but may be limited by initial guesses for weights and a narrower exploration of possibilities.
#
# Limitations of Both Approaches:
#
# Monte Carlo Limitations: Results depend on iterations, and high computational costs can limit efficiency. Historical returns may not capture future volatility or correlation shifts.
#
# Scipy Optimization Limitations: Sensitivity to initial conditions may lead to local minima, and the assumption of normal return distribution may not hold during extreme market events.
#
# To enhance analysis, consider:
#
# * Dynamic Risk Modeling: Adjusting risk models for changing correlations and volatilities.
# * Transaction Costs and Liquidity Constraints: Factoring in trading costs and asset liquidity in optimization models.
# * Non-Normal Return Distributions: Accounting for tail risk and skewness in return distributions.
